# %% [markdown]
# # Day 23 Pre-Class Assignment: Random Numbers
# ### <p style="text-align: right;"> &#9989; Put your name here</p>
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*B7d5Fr27lsH3uHvzF720IA.png" width=300px>
#
# ## Goals for today's pre-class assignment
#
# * Explore different methods for generating random numbers
# * Pratice using the `if`/`elif`/`else` keywords combined with random numbers
#
# The theme of the next few assignments is creating and using random numbers to do a wide range of things, such as modeling randomness that naturally needs to be in our models, or using them to solve problems that would otherwise be too difficult to solve.

# %% [markdown]
# ## Assignment instructions
#
# **This assignment is due by 11:59pm the day before class,** and should be uploaded into the appropriate "Pre-class assignments" submission folder.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ---
# ## Revisiting random numbers
#
# We've already been using random numbers in a variety of ways in this course, but the next class or so of material will use random numbers in a number of new modeling contexts.  As a reminder of some of the ways we can access random numbers in Python, re-watch the following video (if you want a refresher):

# %%
# You are encourage to watch the video in full-screen mode
from IPython.display import YouTubeVideo
YouTubeVideo("fF841G53fGo",width=640,height=360)  # random numbers

# %% [markdown]
# Here are some of the imports we will use in this assignment. Notice that we're importing both `random` *and* `numpy`, which also has a `random` module.  There is also an example for how you can set a specific seed for the `random` module and the `np.random` module, which can be useful for testing code to ensure that you understand the results. **Note**: If you want to use a specific seed, you need to make sure the call to the `seed` function is before the command that is generating the random numbers.

# %%
import random
import matplotlib.pyplot as plt
import timeit
import numpy as np
import seaborn as sns
sns.set_style('ticks')
sns.set_context('notebook')

random.seed(1) # this initializes the seed - see question 6 below
np.random.seed(1)

# %% [markdown]
# ### Practicing random number generation
#
# The following questions are designed to give you a bit of practice with generating a variety of random numbers. Make sure you are able to accomplish all the tasks included below.

# %% [markdown]
# **Question 1**: Write code below to generate 100 random **floats** uniformly distributed between 0 and 1. Plot a histogram of the result values. What happens to your histogram as you generate more values?

# %%
# your code here

# %%
### ANSWER ###
fs = np.random.random(100)
plt.hist(fs);

# %% [markdown]
# **Question 2**: Generate an array with 100 random **integers** uniformly distributed between -1 and 3. Plot a histogram of those values.

# %%
# your code here

# %%
### ANSWER ###
ints = np.random.randint(-1,4,100)
plt.hist(ints);

# %% [markdown]
# **Question 3**: Write code below to generate 10, 100, 1000, and 10000 random **floats** in the interval $[-5,5]$ and make a histogram for each case. Create a markdown cell after the code and comment on what patterns you see. Use NumPy's random module for getting numbers from a [uniform distribution](https://numpy.org/doc/stable/reference/random/generated/numpy.random.uniform.html) for this problem.

# %%
# your code here

# %%
### ANSWER ###
fig, ax = plt.subplots(1, 4, figsize = (26, 4), )
for i, count in enumerate([10,100,1000,10000]):
    vals = np.random.uniform(-5,5,size=count)
    ax[i].hist(vals)
    ax[i].set_title(f'N = {count}')

# %% [markdown]
# **Question 4**:  Use NumPy's `random` module to produce random numbers from a [normal distribution](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) with a mean of 50 and a standard deviation of 20, and generate arrays with 10, 100, 1000, and 10000 samples. Plot the results to see if it converges to a "bell curve" as you increase the number of samples.

# %%
# your code here

# %%
### ANSWER ###
mean = 50
stddev = 20

fig, ax = plt.subplots(1, 4, figsize = (26, 4), )
for i, count in enumerate([10,100,1000,10000]):
    vals = np.random.normal(mean,stddev,size=count)
    ax[i].hist(vals, bins=20)
    ax[i].set_title(f'N = {count}')

# %% [markdown]
# **Question 5**:
# Broadly across science and engineering you will come across a very wide range of different types of random numbers. We have looked at three different options above:
# 1. floats chosen uniformly between two values,
# 2. integers chosen uniformly between two values
# 3. floats chosen that come from a normal distribution (the so-called ["bell curve"](https://en.wikipedia.org/wiki/Normal_distribution))
#
# Next, look through [this list of Python's different choice for distributions](https://numpy.org/doc/stable/reference/random/generator.html#distributions) and pick three. Make a subplot with one row and three columns that compares the three distributions you chose using 1000 samples for each plot. Label as usual, and put a title that has the name of the distribution.

# %%
# your code here

# %%
### ANSWER ###

# For this answer, we're just showing a variety of options, 
# we're not sticking to the "3 plots in one row" format

fig, axs = plt.subplots(2,3, figsize=(10,5))

N = 10_000
ax = axs.flatten()

vals = np.random.beta(1, 0.5, N)
ax[0].hist(vals, bins=20)
ax[0].set(ylabel = "Counts", title ="Beta")

vals = np.random.binomial(1, 0.5, N)
ax[1].hist(vals, bins=20)
ax[1].set(ylabel = "Counts", title ="Binomial")

vals = np.random.chisquare(1, N)
ax[2].hist(vals, bins=20)
ax[2].set(ylabel = "Counts", title =r"$\chi^2$")

vals = np.random.lognormal(1, 0.5, N)
ax[3].hist(vals, bins=20)
ax[3].set(ylabel = "Counts", title ="Log-normal")


vals = np.random.uniform( low = 0.0, high = 10, size = N)
ax[4].hist(vals, bins=20)
ax[4].set(ylabel = "Counts", title ="Uniform")


vals = np.random.normal(1, 0.5, N)
ax[5].hist(vals, bins=20)
ax[5].set(ylabel = "Counts", title ="Normal")

plt.tight_layout()

# %% [markdown]
# **Question 6**: As we mentioned in a prior assignment, one of the interesting aspects of random number generators are that they are not **entirely** random! Think about this for a moment: computers are designed to be able to calculate very precise things with very precise instructions - how could one get randomness out of that? If the computer is following precise rules, it will only know to follow exactly those rules the next time. The way it works is that it starts with some number - _which is the seed defined above_ - and that generates a sequence; a different seed will generate a different sequence. This is very important: if you want to generate that same sequence again, you can. This means that you can make your code reproducable, which is crucial for testing and debugging your code -- often you really don't want a _truly_ random sequence! On the other hand, once you are ready to put your code in use, you can choose something like the current time to generate the seed, and that will be a new and unique sequence.
#
# Your **goal** is to show that specifying a seed will allow you to create reproducible sequence of numbers. To do this, write a short code that uses subplots to make a 2x2 array of plots. For the subplots located at positions [0,0] and [0,1], create a histogram of 1000 random numbers using the same seed (example seed = 456). For the subplots located at positions [1,0] and [1,1], create a histogram of 1000 random numbers using the same seed but different than the first row (example seed = 789). You can use any of the random number generators of your choice (e.g. uniform).

# %%
### ANSWER ###

fig, ax = plt.subplots(2,2, figsize = (10, 5))

np.random.seed(456)
vals = np.random.random(1000)
print(vals[0:3])
ax[0,0].hist(vals, bins=20)
np.random.seed(456)
vals = np.random.random(1000)
print(vals[0:3])
ax[0,1].hist(vals, bins=20)

np.random.seed(789)
vals = np.random.random(1000)
print(vals[0:3])
ax[1,0].hist(vals, bins=20)
np.random.seed(789)
vals = np.random.random(1000)
print(vals[0:3])
ax[1,1].hist(vals, bins=20);
# Out:
# [0.24875591 0.16306678 0.78364326]
# [0.24875591 0.16306678 0.78364326]
# [0.32333482 0.23024711 0.79377887]
# [0.32333482 0.23024711 0.79377887]

# %% [markdown]
# **Question 7**: Explain what this code does.
# ```
# import numpy as np
#
# foo = ['a', 'b', 'c', 'd', 'e']
# print(np.random.choice(foo))
# ```
#
# How would you change the code to choose more than one thing? What if you wanted the choices to be unique?

# %% [markdown]
# *Put your answer here*

# %%
# Feel free to write code to test things out here

# %%
### ANSWER ###
import numpy as np

foo = ['a', 'b', 'c', 'd', 'e']
print(np.random.choice(foo))

print(np.random.choice(foo,size=5))

print(np.random.choice(foo,size=2,replace=False))
# Out:
# a
# ['e' 'a' 'a' 'b' 'a']
# ['e' 'd']

# %% [markdown]
# ### A reminder about "elif" statements
# When trying to evaluate conditions to make a decision in your code, sometimes `elif` is used when there are more than two conditions that we want to check in order to decide how the code behaves. Here is a simple example for how `elif` can be used. You've likely already used `elif` for code you've written, but this should be a nice reminder if you haven't done it in a while. Note that this simple example doesn't use `else` at all -- can you think of a way that you might rewrite this in a way that would? **Run the code a few times to confirm for yourself that it works as you expect when then random number changes.**

# %%
import random
x = random.randint(-1,5)
print(x)
if x < 3 and x >-1:
    print("too small!")
elif x > 3:
    print("too big!")
elif x == 3:
    print("perfect!")
elif x == -1:
    print("negative?")
# Out:
# 0
# too small!

# %% [markdown]
# **Question 8**: Use a random number generator to simulate the roll of a die (from 1 to 6); then use `if`/`elif`/`else` to sort the outcome. Count how many times 1 appears, how many times 6 appears, and also how many times a non-1 non-6 number appears.
# Try this for 100, 1000, 10000 times. Does the number of 1's and 6's appear to converge to 1/6 as the number of rolls increases?

# %%
### ANSWER ###

for count in [100,1000,10_000]:
    ones = 0
    sixes = 0
    other = 0
    for i in range(count):
        roll = random.randint(1,6)
        if roll == 1:
            ones += 1
        elif roll == 6:
            sixes += 1
        else:
            other += 1
    fractions = [ones/count,sixes/count,other/count]
    print("1/6 = ",1/6)
    print(fractions)
# Out:
# 1/6 =  0.16666666666666666
# [0.17, 0.21, 0.62]
# 1/6 =  0.16666666666666666
# [0.166, 0.161, 0.673]
# 1/6 =  0.16666666666666666
# [0.1633, 0.1642, 0.6725]

# %% [markdown]
# Some possibly useful additional resources:
#
# * Look up the extra functions associated with the random module
# * [Python "random" module documentation](https://docs.python.org/3.11/library/random.html)
# * [Numpy "random" module](https://numpy.org/doc/stable/reference/random/index.html)
#
# And here are some links on what you might use random numbers to do in programming and how to "best" use random seeds in Python:
#
# * [Wikipedia article on "Applications of randomness"](https://en.wikipedia.org/wiki/Applications_of_randomness)
# * [Wikipedia article on random number generation](https://en.wikipedia.org/wiki/Random_number_generation)
# * [Stop using Numpy's `random.seed`](https://builtin.com/data-science/numpy-random-seed)

# %% [markdown]
# ---
# ### Assignment wrapup
#
# Please fill out the form that appears when you run the code below.  **You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://forms.office.com/r/L7tKvVciTd" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://forms.office.com/r/L7tKvVciTd"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "Pre-class assignments" folder and upload it there.
#
# See you in class!

# %% [markdown]
# &#169; Copyright 2026,  The Department of Computational Mathematics, Science and Engineering at Michigan State University.
