# %% [markdown]
# # CMSE 801 - Day 14
# ## Command Line Interface
#
# ### Oct 26, 2022

# %% [markdown]
# ## General Course Announcements
#
# * Return on the midterm next class
# * Homework #3 is now due **Tuesday Nov 1 before 11:59 p.m.**
# * Homework #4 is released and is due Nov 14 before 11:59 p.m.
# * Return on project proposals next class

# %% [markdown]
# ## Questions/comments from Day 14 PCA
#
# * What are the advantages and disadvantages of using CLI?
# * How to type into the command?
# * Could you give a visual of how the CLI file structure works?
# * Where does python live relative to working directories?

# %% [markdown]
# ## Let us review the pre-class assignment!

# %% [markdown]
# ## CLI can be useful in your project! You should use JupyterHub instead of your own computer!
