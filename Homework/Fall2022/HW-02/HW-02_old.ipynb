# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Put your name here.

# %% [markdown]
# <p > &#9989; Include resources you made use of here.  This includes people from class you worked with over the course of the assignment, including their names and the capacity with which you worked together.  If you utilized online or other resources, include names, weblinks if applicable, and a brief explanation of the capacity with which you used those materials. Please note that while working with other students in the class and googling for information on issues such as syntax and error messages is fine, it is expected that you are not directly copying materials from either other students or websites.  In particular, you should be able to explain how your code works without either of these resources available.

# %% [markdown]
# # __CMSE  801 &ndash; Fall 2022__
#
# <img src="https://cmse.msu.edu/sites/_cmse/assets/Image/image002.jpg"
#      alt="CMSE Logo"
#      align="right"
#      height="100"
#      width="100" />
#
# # Homework 2: Biofilms resistance
#
# In this homework, you will use Numpy and Matplotlib to study the biofilms resistance to silver nanoparticles (AgNPs). This should serve as a good assessment of what you understand at this point in the course. Make sure to use Slack and help room hours if you run into issues!
#
# A biofilm, the dominant microbial form in nature, can be defined as a bacterial community in which bacteria are protected by a polymetric extracellular matrix. A biofilm can be up to 1000 times more resistant to antimicrobials than free-floating bacteria. Thus, antimicrobial resistance is among the 10 top threats that human are facing, according to the [World Health Organization](https://www.who.int/news-room/fact-sheets/detail/antimicrobial-resistance).
#
# As a young scientist, you wish to investigate the bacterial resistance to antimicrobials using _Vibrio cholerae_ as a model microorganism, that is able to form a strong biofilm. This pathogen predominantly lives in aquatic environments and is the causative agent of cholera, a virulent disease that still affects millions of people, according to the World Health Organization. You therefore make some experiments to weaken the bacteria, both in free-floating form and biofilm state, using silver nanoparticles (AgNPs) and hopefully come up with a new antimicrobial strategy.
#
# After a literature review, you learn that the bacteria _Vibrio cholerae_ in the biofilm form produce an extracellular matrix composed mainly by three proteins, namely RbmA, Bap1 and RbmC.
# You then do experiments using the bacterial _Vibrio cholerae_ strain called rugose and the following four mutants to study the effect of the proteins on the resistance to AgNPs:
#
# * mutant 1: _Vibrio cholerae_ without the protein RbmA called R$\Delta$bmA
# * mutant 2: _Vibrio cholerae_ without the protein Bap1 called R$\Delta$bap1
# * mutant 3: _Vibrio cholerae_ without the protein RbmC called R$\Delta$bmC
# * mutant 4: _Vibrio cholerae_ without all the 3 proteins (RbmA, Bap1 and RbmC) called R$\Delta$ABC
#
# **Full disclosure**: This homework was created in collaboration with a postdoctoral researcher in microbiology and chemistry engineering with an interest in biofilms. I am not an expert in this subject!

# %% [markdown]
# ## Goals
#
# ### By the end of the homework assignment you will have practiced:
#
#
# 1. Loading and saving data using NumPy
# 2. Making a variety of plots in Matplotlib
# 3. Creating NumPy arrays
# 4. Defining functions that manipulate NumPy arrays
# 5. Comparing models to data "by eye"

# %% [markdown]
# ## Assignment instructions
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# **This assignment is due at 11:59pm on Wednesday, Oct 12.** It should be uploaded into the "Homework Assignments" dropbox folder for Homework #2.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ## Part 1: Preliminary (1 point)

# %% [markdown]
# **Question 1**: Make sure you set up your notebook to produce matplotlib plots and import the right modules, as well NumPy.

# %%
# Put your code here

# %%
### ANSWER

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Part 2: Free-floating bacteria (17 points)
#
# To first assess the impact of silver nanoparticles on _Vibrio cholerae_ free-floating bacteria, meaning that the extracellular matrix is not produced and no biofilm is formed, you measure the bacterial growth in the presence of AgNPs for all the 5 strains. You compare these data sets to the growth without AgNPs. The bacterial growth is quantified by measuring the optical density at 600 nm (OD$_{600}$) during 24 hours. The experimental data are contained in the file _OD600.csv_. You have repeated your experiments at least three times for each _Vibrio cholerae_ strain and condition. Your goal is now to interpret your data.
#
# **Hint**: it is always a good idea to take a look to the file before loading it.

# %% [markdown]
# **Question 2**: Extract from the file the time, and the corresponding data with and without AgNPs for each 5 strains (rugose and mutant 1 to 4). So you should have eleven arrays: one for the time, and two for the rugose and each mutant.

# %%
# Put your code here

# %%
### ANSWER
time = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(0))
rugose_noNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(1,2,3,4))
rugose_withNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(5,6,7,8))
mutant1_noNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(10,11,12,13))
mutant1_withNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(14,15,16,17))
mutant2_noNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(19,20,21))
mutant2_withNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(22,23,24,25))
mutant3_noNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(27,28,29))
mutant3_withNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(30,31,32))
mutant4_noNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(34,35,36,37))
mutant4_withNP_data = np.loadtxt("OD600.csv", delimiter=',',skiprows=3,usecols=(38,39,40,41))

# %% [markdown]
# **Question 3**: For the rugose, show the curves over time with and without AgNPs using the `scatter` function. Make sure to identify each curve and axis. Put all the plots on one figure using the function `subplots`, so there should be two plots on the figure: one for the rugose with silver nanoparticles and one without it.

# %%
# Put your code here

# %%
### ANSWER
figure, axes = plt.subplots(2,1,figsize=[15,5])
axes[0].scatter(time,rugose_noNP_data[:,0],label='replicate #1')
axes[0].scatter(time,rugose_noNP_data[:,1],label='replicate #2')
axes[0].scatter(time,rugose_noNP_data[:,2],label='replicate #3')
axes[0].scatter(time,rugose_noNP_data[:,3],label='replicate #4')
axes[0].set_xlabel('t (hour)')
axes[0].set_ylabel('OD$_{600}$')
axes[0].legend()
axes[0].title.set_text('Rugose')
axes[1].scatter(time,rugose_withNP_data[:,0],label='replicate #1')
axes[1].scatter(time,rugose_withNP_data[:,1],label='replicate #2')
axes[1].scatter(time,rugose_withNP_data[:,2],label='replicate #3')
axes[1].scatter(time,rugose_withNP_data[:,3],label='replicate #4')
axes[1].set_xlabel('t (hour)')
axes[1].set_ylabel('OD$_{600}$')
axes[1].legend()
axes[1].title.set_text('Rugose with AgNPs')

plt.tight_layout()

# %% [markdown]
# **Question 4**: Noticing the variability in your data due to biological variations, you want to treat them by computing the mean and the standard deviation for each given time. For example, if you have two replicates with ten points in time, you will compute the mean and the standard deviation of the results of the replicates at each time, and have two arrays of ten components for the mean and the standard deviation. Create a function called `treatData` that takes as inputs the data and returns the number of replicates, and the mean and the standard deviation computed at each time.

# %%
# Put your code here
def treatData(data):
    means = []
    stds = []
    for i, od in enumerate(data):
        means.append( np.mean(od))
        stds.append( np.std(od))
    return np.size(data,1), means, stds

# %%
### ANSWER
def treatData(data):
    means = []
    stds = []
    for i, od in enumerate(data):
        means.append( np.mean(od))
        stds.append( np.std(od))
    return np.size(data,1), means, stds

def treatData(data):
    nbReplicat = np.size(data,1)
    nbData = np.size(data,0)
    averageData = np.zeros(nbData)
    stdData = np.zeros(nbData)
    for i in range(nbData):
        averageData[i] = np.mean(data[i,:])
        stdData[i] = np.std(data[i,:])
    return nbReplicat, averageData, stdData

# %% [markdown]
# **Question 5**: Verify the function `treatData` by showing some numerical evidences.

# %%
# Put your code here

# %%
### ANSWER
data = np.array([ [1,2,3], [4,5,6] ])

nbReplicat, averageData, stdData = treatData(data)
print("number of replicats = ", nbReplicat)
print("average array = ", averageData)
print("std array = ", stdData)
# Out:
# number of replicats =  3
# average array =  [2. 5.]
# std array =  [0.81649658 0.81649658]

# %% [markdown]
# **Question 6**: Create a function called `infoData` that has three inputs: the name of the strain, the data with AgNPs and the one without it. The function should return a list containing the name, the number of replicates, the average and the standard deviation for each data. For each strain of _Vibrio cholerae_, create a list containing all relevant information using the function `infoData`.

# %%
# Put your code for the function here

# %%
### ANSWER
def infoData(name, noNP_data, withNP_data):
    OD_600_data = list()
    OD_600_data.append(name)
    nbReplicat, averageData, stdData = treatData(noNP_data)
    OD_600_data.append(nbReplicat)
    OD_600_data.append(averageData)
    OD_600_data.append(stdData)
    nbReplicat, averageData, stdData = treatData(withNP_data)
    OD_600_data.append(nbReplicat)
    OD_600_data.append(averageData)
    OD_600_data.append(stdData)
    return OD_600_data

# %%
# Put your code here

# %%
### ANSWER
rugose_data = infoData('Rugose', rugose_noNP_data, rugose_withNP_data)
mutant1_data = infoData('mutant1', mutant1_noNP_data, mutant1_withNP_data)
mutant2_data = infoData('mutant2', mutant2_noNP_data, mutant2_withNP_data)
mutant3_data = infoData('mutant3', mutant3_noNP_data, mutant3_withNP_data)
mutant4_data = infoData('mutant4', mutant4_noNP_data, mutant4_withNP_data)

# %% [markdown]
# **Question 7**: For each strain of _Vibrio cholerae_, show the average curves over time with the standard deviation as error bars. One plot should show the results of the strain with AgNPs and without it. Put all the plots in one figure using the function `subplots`, so there should be five plots in the figure: one for each strain of _Vibrio cholerae_. Label the axis and the title, and show the legend.
#
# **Hint**: the option `errorbar` of matplotlib could be useful.

# %%
# Put your code here

# %%
### ANSWER
figure, axes = plt.subplots(5,1,figsize=[15,15])
axes[0].errorbar(time, rugose_data[2], yerr=rugose_data[3], label='without AgNPs')
axes[0].errorbar(time, rugose_data[5], yerr=rugose_data[6], label='with AgNPs')
axes[0].set_xlabel('t (hour)')
axes[0].set_ylabel('OD$_{600}$')
axes[0].title.set_text('Rugose')
axes[0].legend()
axes[1].errorbar(time, mutant1_data[2], yerr=mutant1_data[3], label='without AgNPs')
axes[1].errorbar(time, mutant1_data[5], yerr=mutant1_data[6], label='with AgNPs')
axes[1].set_xlabel('t (hour)')
axes[1].set_ylabel('OD$_{600}$')
axes[1].legend()
axes[1].title.set_text('Mutant 1')
axes[2].errorbar(time, mutant2_data[2], yerr=mutant2_data[3], label='without AgNPs')
axes[2].errorbar(time, mutant2_data[5], yerr=mutant2_data[6], label='with AgNPs')
axes[2].set_xlabel('t (hour)')
axes[2].set_ylabel('OD$_{600}$')
axes[2].legend()
axes[2].title.set_text('Mutant 2')
axes[3].errorbar(time, mutant3_data[2], yerr=mutant3_data[3], label='without AgNPs')
axes[3].errorbar(time, mutant3_data[5], yerr=mutant3_data[6], label='with AgNPs')
axes[3].set_xlabel('t (hour)')
axes[3].set_ylabel('OD$_{600}$')
axes[3].legend()
axes[3].title.set_text('Mutant 3')
axes[4].errorbar(time, mutant4_data[2], yerr=mutant4_data[3], label='without AgNPs')
axes[4].errorbar(time, mutant4_data[5], yerr=mutant4_data[6], label='with AgNPs')
axes[4].set_xlabel('t (hour)')
axes[4].set_ylabel('OD$_{600}$')
axes[4].legend()
axes[4].title.set_text('Mutant 4')
plt.tight_layout()

# %% [markdown]
# **Question 8**: According to these results, what could you deduce about the impact of AgNPs on free-floating _Vibrio cholerae_?

# %% [markdown]
# ### ANSWER
#
# The silver nanoparticules prevent the free-floating bacteria to grow for all strains.

# %% [markdown]
# **Question 9**: Now that you have treated all your data, you want to save them in a _.txt_ file. To do so, you will use the function `np.savetxt` to save a file containing the time, the average and the standard deviation curves (with and without AgNPs) for each strain of _Vibrio cholerae_. In the header, you want to provide a short description of your data, such as the name of the strain, number of replicates, structure of the file, etc. You should then have five _.txt_ files.

# %%
# Put your code here

# %%
### ANSWER
data = np.zeros((len(rugose_data[2]),5))
data[:,0] = time
data[:,1] = rugose_data[2]
data[:,2] = rugose_data[3]
data[:,3] = rugose_data[5]
data[:,4] = rugose_data[6]
np.savetxt("rugose.txt",data, header="strain: rugose, 4 replicates with AgNPs, 4 replicates without AgNPs, structure: time, average and standard deviation with AgNPs, average and standard deviation without AgNPs.", comments="")

data = np.zeros((len(mutant1_data[2]),5))
data[:,0] = time
data[:,1] = mutant1_data[2]
data[:,2] = mutant1_data[3]
data[:,3] = mutant1_data[5]
data[:,4] = mutant1_data[6]
np.savetxt("mutant1.txt",data, header="strain: mutant 1, 4 replicates with AgNPs, 4 replicates without AgNPs, structure: time, average and standard deviation with AgNPs, average and standard deviation without AgNPs.", comments="")

data = np.zeros((len(mutant2_data[2]),5))
data[:,0] = time
data[:,1] = mutant2_data[2]
data[:,2] = mutant2_data[3]
data[:,3] = mutant2_data[5]
data[:,4] = mutant2_data[6]
np.savetxt("mutant2.txt",data, header="strain: mutant 2, 3 replicates with AgNPs, 4 replicates without AgNPs, structure: time, average and standard deviation with AgNPs, average and standard deviation without AgNPs.", comments="")

data = np.zeros((len(mutant3_data[2]),5))
data[:,0] = time
data[:,1] = mutant3_data[2]
data[:,2] = mutant3_data[3]
data[:,3] = mutant3_data[5]
data[:,4] = mutant3_data[6]
np.savetxt("mutant3.txt",data, header="strain: mutant 3, 3 replicates with AgNPs, 3 replicates without AgNPs, structure: time, average and standard deviation with AgNPs, average and standard deviation without AgNPs.", comments="")


data = np.zeros((len(mutant4_data[2]),5))
data[:,0] = time
data[:,1] = mutant4_data[2]
data[:,2] = mutant4_data[3]
data[:,3] = mutant4_data[5]
data[:,4] = mutant4_data[6]
np.savetxt("mutant4.txt",data, header="strain: mutant 4, 4 replicates with AgNPs, 4 replicates without AgNPs, structure: time, average and standard deviation with AgNPs, average and standard deviation without AgNPs.", comments="")

# %% [markdown]
# ## Part 2: Biofilm state (7 points)
#
# Now you want to evaluate the effect of AgNPs on _Vibrio cholerae_ biofilm form, meaning the extracellular matrix with the proteins is produced. You add the AgNPs to the mature biofilm for each five strains and measure the number of colony forming units called CFU, which corresponds to the number of bacteria within the biofilm. You compare these data sets to the values without AgNPs. The experimental data are contained in the file _CFU.csv_. You have repeated your experiments at least three times for each _Vibrio cholerae_ strain and condition. Your goal is now to interpret your data.
#
# **Hint**: it is always a good idea to take a look to the file before loading it.

# %% [markdown]
# **Question 10**: Extract from the file the corresponding data with and without AgNPs for each five strains (rugose and mutant 1 to 4). Each strain has multiple replicates for a total of nine. So you should have ten arrays: two for the rugose and each mutant.

# %%
# Put your code here

# %%
### ANSWER
rugose_noNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(0))
rugose_withNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(6))
mutant1_noNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(1))
mutant1_withNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(7))
mutant2_noNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(2))
mutant2_withNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(8))
mutant3_noNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(3))
mutant3_withNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(9))
mutant4_noNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(4))
mutant4_withNP_data_CFU = np.loadtxt("CFU.csv", delimiter=',',skiprows=2,usecols=(10))

# %% [markdown]
# **Question 11**: Compute the mean of each strain's data with and without AgNPs, and plot the results into two bar charts in logarithm scale: one with AgNPs and one without it. Put all the plots in one figure. Label the axis and the title, and show the legend.

# %%
# Put your code here

# %%
### ANSWER
meanValues = np.zeros(10)
meanValues[0] = rugose_noNP_data_CFU.mean()
meanValues[1] = mutant1_noNP_data_CFU.mean()
meanValues[2] = mutant2_noNP_data_CFU.mean()
meanValues[3] = mutant3_noNP_data_CFU.mean()
meanValues[4] = mutant4_noNP_data_CFU.mean()
meanValues[5] = rugose_withNP_data_CFU.mean()
meanValues[6] = mutant1_withNP_data_CFU.mean()
meanValues[7] = mutant2_withNP_data_CFU.mean()
meanValues[8] = mutant3_withNP_data_CFU.mean()
meanValues[9] = mutant4_withNP_data_CFU.mean()

# figure
name = np.array(['rugose','mutant 1', 'mutant 2', 'mutant 3', 'mutant 4'])
figure, axes = plt.subplots(2,1,figsize=[5,10])
axes[0].bar(name,meanValues[0:5],log=True, align='center')
axes[0].set_ylim(1,10*meanValues.max())
axes[0].title.set_text('without AgNPs')
axes[0].set_xlabel("strain")
axes[0].set_ylabel("CFU/ml")
axes[1].bar(name,meanValues[5:11],log=True, align='center')
axes[1].set_ylim(1,10*meanValues.max())
axes[1].title.set_text('with AgNPs')
axes[1].set_xlabel("strain")
axes[1].set_ylabel("CFU/ml")
plt.tight_layout()

# %% [markdown]
# **Question 12**: According to these results, what could you deduce about the impact of AgNPs on _Vibrio cholerae_ biofilms?

# %% [markdown]
# The silver nanoparticles kills bacteria in the mutant 4 biofilm. Regarding the other strains, we could conclude that AgNPs weaken the biofilm, meaning that they reduce the number of colony units.

# %% [markdown]
# ## Part 3: Modeling bacteria growth (8 points)
#
# Now that you have analyzed your data, you want to fit a model on the data of the rugose OD$_{600}$ mean without AgNPs as a first attempt to model bacteria growth. You decide to fit a third degree polynomial of the form
# \begin{equation*}
# p(t) = a_0 + a_1\,t + a_2\,t^2 + a_3\,t^3
# \end{equation*}
# and an exponential function of the form
# \begin{equation*}
# f(t) = c_0\,e^{c_1\,t}
# \end{equation*}
# where $a_0, a_1, a_2, a_3, c_0$ and $c_1$ are coefficients to be determined. Since you do not know yet how to compute these coefficients, you ask a collegue in applied mathematics for help. He provides you these values:
# \begin{equation*}
# \begin{aligned}
# a_0 =&\,\, 3.65619325\times 10^{-2}    \\
# a_1 =&\,\, -2.48070216 \times 10^{-2}    \\
# a_2 =&\,\, 3.46557197\times 10^{-3}    \\
# a_3 =&\,\, -8.42584437\times 10^{-5}    \\
# c_0 =&\,\, 0.00317156     \\
# c_1 =&\,\, 0.22424461    \\
# \end{aligned}
# \end{equation*}

# %% [markdown]
# **Question 13**: Create two functions, called `polynomial_model` and `exponential_model`, that compute the values of OD$_{600}$ for a given vector containing different time values. The functions take as inputs the time and the values of the coefficients, and return the values of the model.

# %%
# Put your code here

# %%
### ANSWER
def polynomial_model(t,a):
    p = a[0] + a[1]*t + a[2]*t**2 + a[3]*t**3
    return p 

def exponential_model(t,c):
    f = c[0]*np.exp(c[1]*t)
    return f

# %% [markdown]
# **Question 14**: Plot the experimental data, the polynomial model and the exponential model on the same graph.

# %%
# Put your code here

# %%
### ANSWER
a = np.array([3.65619325e-2, -2.48070216e-2, 3.46557197e-3, -8.42584437e-5])
c = np.array([0.00317156, 0.22424461])
plt.figure(figsize=[15,5])
plt.scatter(time,rugose_data[2])
plt.plot(time,polynomial_model(time,a),"b",linestyle="-")
plt.plot(time,exponential_model(time,c),"k",linestyle="-.")
plt.title('Growth modeling for rugose')
plt.xlabel("t (hour)")
plt.ylabel("OD$_{600}$")
# Out:
# Text(0, 0.5, 'OD$_{600}$')

# %% [markdown]
# **Question 15**: By "eye", are these models appropriate? Explain your reasoning.

# %% [markdown]
# <font size="+3">&#9998;</font> Put your answer here

# %% [markdown]
# ### ANSWER
# The third degree polynomial model has a decrease at the beginning and also gives negative values, which are not possible. The exponential model does not fit the general trend of the data from 10 hours to 24 hours. So these models are not appropriate.

# %% [markdown]
# **Question 16**: Plot the experimental data, the polynomial model and the exponential model for a time interval of $[0,15]$ h using these coefficients:
#
# \begin{equation*}
# \begin{aligned}
# a_0 =&\,\, 3.05949036\times 10^{-3}    \\
# a_1 =&\,\, 2.25810851 \times 10^{-3}    \\
# a_2 =&\,\, -8.01413073\times 10^{-4}    \\
# a_3 =&\,\, 9.04713572\times 10^{-5}    \\
# c_0 =&\,\, 0.00218177     \\
# c_1 =&\,\, 0.27666526     \\
# \end{aligned}
# \end{equation*}

# %%
# Put your code here

# %%
### ANSWER
a = np.array([3.05949036e-3, 2.25810851e-3, -8.01413073e-4, 9.04713572e-5])
c = np.array([0.00218177, 0.27666526])
val = rugose_data[2]
plt.figure(figsize=[15,5])
plt.scatter(time[0:61],val[0:61])
plt.plot(time[0:61],polynomial_model(time[0:61],a),"b",linestyle="-")
plt.plot(time[0:61],exponential_model(time[0:61],c),"k",linestyle="-.")
plt.title('Growth modeling for rugose')
plt.xlabel("t (hour)")
plt.ylabel("OD$_{600}$")
# Out:
# Text(0, 0.5, 'OD$_{600}$')

# %% [markdown]
# **Question 17**: By "eye", are these models appropriate? Explain your reasoning and the difference between your results of question 15 and 17.

# %% [markdown]
# <font size="+3">&#9998;</font> Put your answer here

# %% [markdown]
# ### ANSWER
# The polynomial model is better suited than the exponential model to represent the general trend of data of the rugose growth. The difference between the results stem from the consideration of the plateau at the end of the experimental data, which indicates an overpopulation of bacteria. Indeed, our goal is to model the bacteria growth which happens roughly during the first 15 hours under these conditions.

# %% [markdown]
# ---
# ## Assignment wrap-up
#
# Please fill out the form that appears when you run the code below.  **You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://docs.google.com/forms/d/e/1FAIpQLSc-0Djvg-gQJnBhBNWAT3t7cdBqQJfypC4qdspk2H3Eq6ACzg/viewform?usp=sf_link" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://docs.google.com/forms/d/e/1FAIpQLSc-0Djvg-gQJnBhBNWAT3t7cdBqQJfypC4qdspk2H3Eq6ACzg/viewform?usp=sf_link"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "Homework Assignments" folder, find the dropbox link for Homework #2, and upload it there.
