# %% [markdown]
# # 1. Part 1 (35 points)
#
#  - Q1 (15 pts):
#     - 2 pts: importing modules
#     - 3 pts: init values are defined
#     - 2 pts: time range is correct
#     - 6 pts: function is defined correctly, accepting parameters, returning derivatives
#     - 2 pts: results from ideint are saved for later use
#
#
#  - Q2 (8 pts):
#      - 4 pts: plot is shown
#      - 2 pts: lines have different colors
#      - 1 pt: labels on plot
#      - 1 pt: legend on plot
#
#
#  - Q3 (2 pts):
#      - 1 pt: if the answer indicates the lines are growing linearly and parallel (the same)
#      - 1 pt: if the answer indicates their explanation why/why not
#
#
#  - Q4 (4 pts):
#      - give all points for plot for first 10 hours unless:
#         - deduct 1pt if the range is not right
#         - deduct 1pt if not plotted by slicing
#
#
#  - Q5 (1 pts):
#      - 1pt: if the answer indicated time around 2h
#
#
#  - Q6 (5 pts):
#      - 2 pts: function and computation is done again (using whatever method)
#      - 2 pts: plotted the right plot, with right time scale
#         - can deduct 1 pt if the plot is NOT clear (no labels, no title, lines with same color, ...)
#      - 1 pt: anwser indicates the pollutant in lakes level
