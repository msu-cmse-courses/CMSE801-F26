# %% [markdown]
# # CMSE 801: Quiz 3 (Fall 2023)
#
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **You cannot use ChatGPT or any other artificial intelligence tool. If you do you get 0 points!!!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **28 points** possible on this quiz. **If you get stuck _move on to another part of the quiz to earn some points there!_**

# %% [markdown]
# ---
# <a id="toc"></a>
#
# ## Table of Contents
#
# [Part 1. Love equations](#part_1)  (12 points)
#
# [Part 2. A solution of Water and Fire](#part_2)  (8 points)
#
# [Part 3. Analysis](#part_3)  (8 points)

# %%
points_list = [13, 8, 7]

print(f"The total number of points is : {sum(points_list)}")

# %%
# %pylab
# %matplotlib inline
import pandas as pd
import seaborn as sns
from scipy.integrate import solve_ivp

sns.set_context('talk')

# %% [markdown]
# ---
# <a id="part_1"></a>
#
# # Part 1. Modeling a system
#
# In this question, you're going to think about how one could build a model to study how the biomass (https://en.wikipedia.org/wiki/Biomass_(ecology)) in a forest changes as a function of time. In particular, we'll be thinking about how biomass moves between living trees, dead trees, and humus, which is defined to be "the organic component of soil, formed by the decomposition of leaves and other plant material by soil microorganisms." We can model this system with the following equations:
#
# $$ \frac{dH}{dt} = a H + b D $$
# $$ \frac{dD}{dt} = c D + d L $$
# $$ \frac{dL}{dt} = e L $$
#
# where $H$ is the biomass that has decayed in humus, $D$ is the biomass in dead trees, and $L$ is the biomass in living trees. Given that we're talking about the life and death of trees, we assume will use **decades** (10s of years) as our unit of time, $t$. This means that, for example, $t = 2$ would be _20 years_.

# %% [markdown]
# ## Write the equations (13 points):
#
# &#9989;&nbsp; **Task:** Write a function called `biomass_eq` that computes the above equations
#
# **IMPORTANT:** This function will be used by `solve_ivp`, therefore the inputs should be in a specific order and grouped in a specified way. Check HW, PCA, ICA, or internet for the correct way.
#
# - Make sure the inputs are in the correct order **(2 points)**.
# - Make sure you unpack the current state of the system in the correct order **(2 points)**
# - Make sure the constants are passed in the correct order **(2 points)**. **NOTE:** Do not hardcode these!!!
# - Write the correct equations. Check the sign of every variable **(5 points)**
# - Make sure you are returning the derivatives in the correct order **(2 points)**

# %%
# Put your code here

# %%
### ANSWER ###
def biomass_eq(t, vals, constants):
    """"""
    x, y, z = vals
    a, b, c, d, e = constants
    
    dxdt = a * x + b*y
    dydt = c*y + d*z
    dzdt = e*z

    return dxdt, dydt, dzdt

# %% [markdown]
# ---
# <a id="part_2"></a>
#
# # Part 2: Solving the equations with `solve_ivp` (8 points)
#
# Solve the above equations using `solve_ivp` with the following initial conditions and parameters
#
# | Scenario      | H0 | D0 | L0 | a | b | c | d | e |
# |---------------|---|---|---|---|---|---|---|---|
# | Water & Fire  | 0 | 0 | 809601 |-1 | 3 |-3 | 5 | -5|
#
# where `H0`, `D0`, and `L0` are the initial values of humus, dead trees, and living trees.
#
# &#9989;&nbsp; **Task:** Complete the cell below by adding code that
#
# - calls `solve_ivp` with the correct parameters **(2 points)**.
# - plots $H$, $D$, $L$ vs time in the **same plot**. Don't forget to label them. **(2 points)**
#
# **NOTE:** I already wrote code for the figure. You only need to plot the lines.
#
# Make sure to
#
# - Pack the initial conditions in the correct order **(2 points)**.
# - Pack the constants in the correct order **(2 points)**.
#
# If you have done things right you should get the following plot
#
# ![image.png](biomass.png)

# %%
# Parameter values to be used
tstart, tend = 0.0, 2.
nsteps = 200
time = np.linspace(tstart, tend, nsteps)

# Initial conditions
H0 = 0.0
D0 = 0.0
L0 = 809601

a, b, c, d, e = -1, +3 , -3, +5, -5


# Start the figure
fig = plt.figure(figsize=(8,6))

# PUT YOUR CODE HERE
    
plt.grid(alpha = 0.3)
plt.legend()
plt.ylabel("Lovers")
plt.xlabel("Time")

# %%
### ANSWER

# Parameter values to be used
tstart, tend = 0.0, 2.
nsteps = 200
time = np.linspace(tstart, tend, nsteps)

# Initial conditions
H0 = 0.0
D0 = 0.0
L0 = 809601

a, b, c, d, e = -1, +3 , -3, +5, -5

fig = plt.figure(figsize=(8,6))

sols = solve_ivp(biomass_eq, 
                 (tstart, tend), 
                 [H0, D0, L0], 
                 t_eval=time,
                 args= [(a, b, c, d, e)])

plt.plot(sols.t, sols.y[0,:], label = "Humus")  
plt.plot(sols.t, sols.y[1,:], label = "Dead")
plt.plot(sols.t, sols.y[2,:], label = "Living")
# 2 points: for each plot 
    # 0.5 correct inputs,
    # 0.5 label
    
plt.grid(alpha = 0.3)
plt.legend()
plt.ylabel("Biomass")
plt.xlabel("Time [decades]")
plt.savefig('biomass.png')
# plt.yscale('log')

# %% [markdown]
# ---
# <a id="part_3"></a>
#
# # Part 3: Analysis (7 points):
#
# &#9989;&nbsp; **Question 1 (3 points)**: At what point in time is the total amount of living trees half of the starting value? Explain how you determined this. **Note**: It is not necessary to write code to solve this and your answer can be approximate (but you should be able to estimate it to within a half a year precision). If you have time, you are encouraged to write code to find a precise solution, but it is not necessary to receive credit.
#
#
# &#9989;&nbsp; **Question 2 (3 points)**: At what point in time does the total amount of biomass in the humus exceed that of the dead trees? Explain how you determined this. **Note**: It is not necessary to write code to solve this and your answer can be approximate (but you should be able to estimate it to within a half a year precision). If you have time, you are encouraged to write code to find a precise solution, but it is not necessary to receive credit.
#
# &#9989;&nbsp; **Question 3 (1 points)**: Which is rising faster, the biomass of humus or the biomass of dead trees?
#
# **NOTE:** You can still answer these questions if you can't get the part above to work. Just look at the plot I show in Part 2 or you can download it from D2L.

# %% [markdown]
# Put your answers here

# %% [markdown]
# ---
#
# # Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz 03, and upload it there.

# %% [markdown]
# ![Moira2](https://media.giphy.com/media/d1E2HnwywoTkES08/giphy.gif)

# %% [markdown]
# &#169; Copyright 2023,  Michigan State University Board of Trustees
