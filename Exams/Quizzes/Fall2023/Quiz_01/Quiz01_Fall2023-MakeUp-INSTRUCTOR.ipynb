# %% [markdown]
# # CMSE 801: Quiz 01 (Fall 2023)
#
# ## <p style="text-align: right;"> &#9989; Put your name here</p>
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **You cannot use ChatGPT or any other artificial intelligence tool. If you do you get 0 points!!!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
#
# There are a total of **34 points** possible on this quiz and each part of the quiz can be done independently. **If you get stuck _move on to another part of the quiz to earn some points there!_**
#
# ![Moira](https://media.giphy.com/media/26gs78HRO8sOuhTkQ/giphy.gif)

# %% [markdown]
# ---
# <a id="toc"></a>
#
# ## Table of Contents
#
# [Part 0. Academic Integrity Statement](#part_0) (1 point)
#
# [Part 1. Variables](#part_1)  (5 points)
#
# [Part 2. Lists and Indexing](#part_2)  (4 points)
#
# [Part 3. Elementwise operations via loops](#part_3) (9 points)
#
# [Part 4. Loops and conditional statements](#part_4) (11 points)

# %%
points_list = [1, 5, 4, 9, 11 ]

print(f"The total number of points is : {sum(points_list)}")

# %% [markdown]
# ### ANSWER (for making sure this gets removed) ###
#
# ## Template Guidelines
#
# **Learning Objectives from Assignments:**
# * Work with number, string, and list data types
# * Learn how to do order of magnitude approximations
# * Write for and while loops
# * Combine lists and loops to compute new values
# * Use python lists to store values
# * Use loops to iterate over a specified range, over a list of values, or until a condition is met
# * Use conditional statements to control code flow
# * Basic debugging
#
# **Learning Objectives the Quiz will assess:**
# * When should students use a For loop vs. while loop
# * What problems can we solve with Loop by index vs. loop by value
# * Calculating and Storing values in lists (within loops)
# * Basic debugging (potentially involving: lists, loops, variables; **this was an implicit learning goal that we didn't work on to explicitly, so don't get carried away with this one**)
#
# **Learning objectives that we don't have time/space for**:
#
# * Using conditional statements, we can try to integrate this into a future quiz.
#
# **Quiz Duration:** 30 minutes
# * This means your TAs/LAs should be able to complete the quiz in at most 10 minutes
#
# **Notes:**
# * The structure and rubric provided here is a suggestion and an example of the difficulty level expected. However, as long as your quiz assesses the learning objectives listed under "Learning Objectives the Quiz will assess" section above, you can differ from this structure. If you aren't sure that your quiz does that, run it by another instructor (lead isntructor, other faculty, TA, or LA)
# * The examples provided are examples and **should not be used directly without changes in any quizzes**
# * These quizzes are important for students to assess how well they understand the material independent of their groups, so when grading, be sure to provide feedback on where points were deducted. **You should also have a clear rubric with clearly stated point values, but you do not need to follow the point values included in this template**.
# * Quizzes should be written with ample time for TAs/LAs to review! **Your TA and LAs should have at least 48 hours to review the quiz before it is given**.
# * Quizzes (and instructor solution with point-by-point rubrics) should be **pushed to the GitHub repo for record-keeping**. Put your section's version in a sub-folder with the name `Section-###` where "###" is your section number.
#
# **Overall Structure:**
#
# * Basic question that assess variable type and scope
# * Basic question about a list (and indexing)
# * Question that probes students knowledge an ability to use for loop by index vs. by value and an opportunity to do some debugging
# * Question with a while loop that has them take an awkward for loop and rewrite it as a while loop

# %% [markdown]
# ---
# <a id="part_0"></a>
#
# # Academic integrity statement (1 points)
#
# [Back to Top](#toc)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# <a id="part_1"></a>
#
# # Part 1. Variables (5 points)
# [Back to Top](#toc)
#
# In the first cell below, define **two** variables: one holding your name as a string and the other holding a number of your choice (_e.g._ the number of pets you have/had or wish to have, the number of people sitting on the same row as you, etc...), as an **integer**.
#
# In the second cell below, write a print statement (using your two variables defined in the first cell) that prints a complete sentence stating your name and the number you choose. Remember to put spaces.

# %%
# define your variables here

# %%
# write your print statement here

# %% [markdown]
#  <font size=6 color="#009600">&#9998;</font> YOUR EXPLANATION GOES HERE

# %%
### ANSWER

name = "Luciano"
table = 0

# 1 points for string of name
# 1 points for table number

# %%
### ANSWER

print("My name is ", name, " and I am sitting at table number " , table )

# 1 point for using print()
# 1 point for calling the name variable
# 1 point for calling the table number variable
# 1 point for a complete sentence (0.5 point if the print statement runs but is not formatted as a complete sentence)

# %% [markdown]
# ---
# <a id="part_2"></a>
#
# # Part 2. Lists and Indexing (4 points)
# [Back to top](#toc)
#
# In the cell below, there is the list of the top 5 shows on Netflix from last week. However, the list does not contain the shows in the right order.
#
# Create a new list with the correct order by **using the elements** of the first list, _i.e._ **use indexing**
#
# Then print the correct list.

# %%
# put your code here
netflix_top5_wrong = [   
    "2. Kountry Wayne: A Woman's Prayer",
    "1. Murdaugh Murders: A Southern Scandal",
    "5. Inside the World's Toughest Prisons",
    "4. Dear Child",
    "3. Virgin River",
]

# %%
# put your code here

# %%
### ANSWER
# top_five = billboard_top5_wrong.sort() # Too easy not allowed
top_five = [billboard_top5_wrong[2],
            billboard_top5_wrong[1],
            billboard_top5_wrong[-1],
            billboard_top5_wrong[-2],
            billboard_top5_wrong[0]
           ]

# 1 points for defining a list
# 1 points for correct order
# 1 points for using indices
# 1 point for printing

# %% [markdown]
# ---
# <a id="part_3"></a>
#
# # Part 3. Elementwise operations via loops (9 points):
# [Back to Top](#toc)
#
# The code cell below contains a list of students grades for Quiz 01. The grades are on a scale 1 -- 30, but the entire quiz is worth only 5% of the total grade.
#
# Your task is to
#
# - multiply each grade by 5/30,
# - store the new grades into a new list called `new_grades`,
# - print the new list `new_grades`

# %%
grades = [8, 24, 13, 3, 18, 5, 17, 19, 17, 2, 19, 12, 24, 8, 17, 29, 22, 16, 28, 22]

# Put your code here

# %%
### ANSWER 
# import numpy as np
# grades = np.random.randint(0, 30, 20)

# for i in grades:
#     print(str(i) + ", ", end = '')

grades = [8, 24, 13, 3, 18, 5, 17, 19, 17, 2, 19, 12, 24, 8, 17, 29, 22, 16, 28, 22]

# 1 point for creating a new list
# 2 point for writing a for loop or a while loop correctly
# 2 point for append correctly
# 2 points for correct math
# 1 for using indexing or value correctly
# 1 point for printing

new_grades = []
for i in grades:
    new_grades.append( i*5/30)

new_grades = []
for i in range(len(grades)):
    g = grades[i] *5/30
    new_grades.append(g)

new_grades = []
i = 0
while i < len(grades):
    g = grades[i] *5/30
    new_grades.append(g)
    i += 1
    
print(new_grades)

# %% [markdown]
# ---
# <a id="part_4"></a>
#
# # 4. Loops and conditional statements (11 points):
# [Back to Top](#toc)
#
# In the code cell below there is an complete working code that does not throw an error, but it does have a bug. The code is supposed to assign a letter grade to each student based on this rubric
#
#         A if greater or equal than 90
#         B if greater or equal than 80 but less than 90
#         C if greater or equal than 70 but less than 80
#         D if greater or equal than 60 but less than 70
#         F if less than 60
#
# At the end the code stores the letter grade into the list `students_letter_grades`.
# However, it gives the wrong answer. Giulia should get a "B" not a "D"

# %%
students_names = ['Giuseppe', 'Giulia', 'Marco','Isabella', 'Mario', 'Federica','Alessandro', 'Valentina', 'Davide','Eleonora', 'Antonio','Martina', 'Roberto', 'Francesca', 'Lorenzo']

students_grades = [85, 81, 51, 87, 59, 64, 70, 66, 93, 85, 76, 77, 67, 96, 69]

students_letter_grades = [] 

for index in range(len(students_grades)):
    
    grade = students_grades[index] 
    
    name = students_names[index]
    
    # PUT HERE YOUR CODE FOR CALCULATING THE LETTER GRADE
    if grade >= 90:
        letter_grade = "A"
    
    if grade >= 80:
        letter_grade = "B"
    
    if grade >= 70:
        letter_grade = "C"
    
    if grade >= 60:
        letter_grade = "D"
    
    if grade < 60:
        letter_grade = "F"
    
    students_letter_grades.append( name + "_" + letter_grade )

print(students_letter_grades)
# Out:
# ['Giuseppe_D', 'Giulia_D', 'Marco_F', 'Isabella_D', 'Mario_F', 'Federica_D', 'Alessandro_D', 'Valentina_D', 'Davide_D', 'Eleonora_D', 'Antonio_D', 'Martina_D', 'Roberto_D', 'Francesca_D', 'Lorenzo_D']

# %% [markdown]
# &#9989;&nbsp; **Part 4.1 (6 points):** In the cell below, answer the following questions
#
# 1. A plain english description of the error in the code and why you get the error. (2 points)
# 2. How would you fix this bug ? (2 points)
# 3. Create a new cell and write your solution in there. (2 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER
#
# 1. The if statements are not correct because I am not catching the range in which they are defined.
#
# 2. Use `elif`

# %%
### ANSWER

students_names = ['Giuseppe', 'Giulia', 'Marco', 
                  'Isabella', 'Mario', 'Federica', 
                  'Alessandro', 'Valentina', 'Davide', 
                  'Eleonora', 'Antonio','Martina', 
                  'Roberto', 'Francesca', 'Lorenzo']


students_grades = [85, 81, 51, 87, 59, 64, 70, 66, 93, 85, 76, 77, 67, 96, 69]

students_letter_grades = []

for index in range(len(students_grades)):
    
    grade = students_grades[index] 
    
    name = students_names[index]
    
    # PUT HERE YOUR CODE FOR CALCULATING THE LETTER GRADE
    if grade >= 90:
        letter_grade = "A"
    
    elif grade >= 80:
        letter_grade = "B"
    
    elif grade >= 70:
        letter_grade = "C"
    
    elif grade >= 60:
        letter_grade = "D"
    
    else:
        letter_grade = "F"
    
    students_letter_grades.append( name + "_" + letter_grade )

print(students_letter_grades)

# %% [markdown]
# &#9989;&nbsp; **Part 4.2 (5 points):** Answer the following questions in the cell below
#
# 1. Is your code "**looping by index**" or "**looping by value**"? (1 point)
# 2. Do you think you could you solve the problem using the other kind of `for` loop? Why or why not? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# - 1. It is looping by index.
# - 2. No we couldn't solve this problem by looping by value, since we need to access two lists.

# %% [markdown]
# ---
#
# # Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.
#
# Go to the **Quizzes** section, find the submission folder link for **Quiz 01**, and upload it there.
#
#
# ![Moira2](https://media.giphy.com/media/d1E2HnwywoTkES08/giphy.gif)

# %% [markdown]
# &#169; Copyright 2023,  Department of Computational Mathematics, Science and Engineering at Michigan State University.
