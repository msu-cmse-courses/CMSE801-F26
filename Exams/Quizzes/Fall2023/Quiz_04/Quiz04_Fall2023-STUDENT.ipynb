# %% [markdown]
# # CMSE 801: Quiz 4 (Fall 2023)
#
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **You cannot use ChatGPT or any other artificial intelligence tool. If you do you get 0 points!!!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **25 points** possible on this quiz and each part of the quiz can be done independently. **If you get stuck _move on to another part of the quiz to earn some points there!_**
#
#
# ![Moira](https://media.giphy.com/media/26gs78HRO8sOuhTkQ/giphy.gif)

# %% [markdown]
# ---
# <a id="toc"></a>
#
# ## Table of Contents
#
# [Part 1. Pandas](#part_1)  (13 points)
#
# [Part 2. Linear Regression](#part_2)  (12 points)

# %%
points_list = [13, 12]

print(f"The total number of points is : {sum(points_list)}")

# %%
# %pylab 
# %matplotlib inline
import pandas as pd
from scipy.optimize import curve_fit

# %% [markdown]
# ---
# <a id="part_1"></a>
#
# # Part 1. Loading, exploring, and masking data with Pandas (13 points)
# [Back to Top](#toc)
#
# <img src="https://cdn.mos.cms.futurecdn.net/E3WFeLCEMJZvB9AFzv84TS.jpg" width=600px style="margin-left: 20px" alt="Image credit: https://blogs.acu.edu/">
#
# &#9989;&nbsp; **Question 1.1 (2 points)**
#
# Load the `diamonds.csv` file provided on D2L **using Pandas** and display the first 10 rows.

# %%
# Put your code here

# %% [markdown]
# As you can see this is a dataset containing information about diamonds. The columns are self-explanatory except for a few, but we won't use those.

# %% [markdown]
# &#9989;  **Question 1.2 (1 point)**: Use `.describe()` to display several summary statistics from the data frame.

# %%
# Put your code here

# %% [markdown]
# &#9989;  **Question 1.3 (4 points)**: Answer the following questions in the next markdown cell
#
# 1. How many columns are in the **entire** dataset?
# 2. Why are there missing columns in the statistical summary?
# 3. How many rows are in the dataset ?
# 4. How much does the most expensive diamond cost ?

# %% [markdown]
# &#9989; **Question 1.4 (3 points)**: An important feature of diamonds is their **clarity**. The figure below tells you the possible level of clarity of a diamond. The best quality is _flawless_ while the worst is _included_.
#
# <img src="https://www.datocms-assets.com/25216/1652905572-d-clarity-chart.jpg?q=25&auto=format&w=2880" width=600px style="margin-left: 20px" alt="Image credit: https://vrai.com/">
#
# Using `.loc` or `.iloc` to display the `carats`, `clarity`, and `price` of the 27748th diamond.
# If you do this correctly you should get these values.
#
#  carat | clarity | price |
# ------:|--------:|------:|
#   1.51 |      IF | 18806 |
#
#
# **Note:** Don't forget that the first diamond has index = 0.

# %%
# Put your code here

# %% [markdown]
# &#9989; **Question 1.5 (3 points)**: You notice that the 27748th diamond is not the most expensive (compare to what you saw/wrote in Question 1.2). Using masking display the line of the **most expensive** diamond.

# %%
# Put your code here

# %% [markdown]
# ---
# <a id="part_2"></a>
#
# # Part 2. Fitting a model to data with `curve_fit` and visualizing the results (12 points)
# [Back to Top](#toc)
#
#
# Do you remember this figure?
#
# <img src="https://i.ibb.co/rZGfsp5/HR-diagram.png" alt="HR-diagram" border="0" width=600>
#
# This time you will fit luminosity vs radius.
#
# &#9989;&nbsp; **Question 2.1 (2 points)**
#
# Load the `stars.csv` file provided on D2L **using Pandas** and display the first **5 rows**.

# %%
# put your code here

# %% [markdown]
# &#9989;&nbsp; **Question 2.2 (3 points)**
#
# In the above plots we notice that the main sequence stars fall on a (almost) straight line in both plots. Since both axis are on a log-log plot we can infer that there exist a power-law relation between the Luminosity, $L$, and radius, $R$. Specifically,
#
# $$ \frac{L}{L_o} = \left( \frac{R}{R_o} \right )^{\beta} $$
#
# Write a function called `lum_model` that computes the relative luminosity according to the equation above. Note that you don't have to do any math on the columns. (3 points)

# %%
# Put your code here

# %% [markdown]
# &#9989;&nbsp; **Question 2.3 (4 points):**
#
# - Use `curve_fit` with the above function to find the parameter $\beta$ by fitting the `Luminosity(L/Lo)` and `Radius(R/Ro)` of the **main sequence stars only** (you'll want to use a mask to select these stars).
#
# - What is the value of $\beta$?

# %%
# Put your code here

# %% [markdown]
# &#9989;&nbsp; **Question 2.4 (3 points):**  Make a plot comparing your model and the data. Don't forget to log-scale your axis, label them, and add a legend.

# %%
# put your code here

# %% [markdown]
# ---
#
# # Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.
#
# Go to the **Quizzes** section, find the submission folder link for **Quiz 03**, and upload it there.
#
#
# ![Moira2](https://media.giphy.com/media/d1E2HnwywoTkES08/giphy.gif)
