# %% [markdown]
# # CMSE 801: Quiz 3 (Spring 2024)
#
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **You cannot use ChatGPT or any other artificial intelligence tool. If you do you get 0 points!!!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **28 points** possible on this quiz. **If you get stuck _move on to another part of the quiz to earn some points there!_**

# %% [markdown]
# ---
# <a id="toc"></a>
#
# ## Table of Contents
#
# - [Part 0. Academic Integrity Statement](#part_0) (1 point)
# - [Part 1. Love equations](#part_1)  (12 points)
# - [Part 2. A solution of Water and Fire](#part_2)  (8 points)
# - [Part 3. Analysis](#part_3)  (8 points)

# %%
points_list = [1, 12, 8, 8]

print(f"The total number of points is : {sum(points_list)}")
# Out:
# The total number of points is : 29

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from scipy.integrate import solve_ivp

sns.set_context('talk')

# %% [markdown]
# ---
#
# # Academic integrity statement (1 point)
#
#
# In the markdown cell below, copy in the [MSU Academic Pledge](https://asmsu.msu.edu/home/initiatives/spartan-code-of-honor/) and sign your name. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else; and that you are using internet resources thoughtfully and within the guidelines provided above.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# <a id="part_1"></a>
#
# # Part 1. Love Equations
#
# ![Tom](https://media.giphy.com/media/HaKdwo6p8WPBK/giphy.gif)
#
# Let's try to model the romance between JD and Elliot in [Scrubs](https://www.imdb.com/title/tt0285403/).
#
# Let $E$ denote the affection that Elliot has for JD and $J$ be the affection that JD
# has for Elliot.
#
# Positive values of $E,J$ indicate **like**, while negative values indicate **dislike**.
#
# A typical system relating the combined changes in affection can be modeled as
#
# $$ \frac{dE}{dt} = a E + b J, $$
#
# $$ \frac{dJ}{dt} = c E + d J, $$

# %% [markdown]
# ## Write the equations (12 points):
#
# &#9989;&nbsp; **Task:** Write a function called `love_eq` that computes the above equations
#
# **IMPORTANT:** This function will be used by `solve_ivp`, therefore the inputs should be in a specific order and grouped in a specified way. Check HW, PCA, ICA, or internet for the correct way.
#
# - Make sure the inputs are in the correct order **(2 points)**.
# - Make sure you unpack the current state of the system in the correct order **(2 points)**
# - Make sure the constants are passed in the correct order **(2 points)**. **NOTE:** Do not hardcode these!!!
# - Write the correct equations. Check the sign of every variable **(4 points)**
# - Make sure you are returning the derivatives in the correct order **(2 points)**

# %%
# Put your code here

# %%
### ANSWER ###
def love_eq(t, love_status, constants):
    """
    Calculate the love/dislike of Elliot and JD.
    
    """
    
    E, J = love_status
    a, b, c, d = constants
    
    dEdt = a*E + b*J
    
    dJdt = c*E + d*J
    
    return dEdt, dJdt

# %% [markdown]
# ---
# <a id="part_2"></a>
#
# # Part 2: A solution of Water and Fire (8 points)
#
# Let's see if we have coded things right by testing it on the `Water & Fire` scenario in which the two lovers cycle through periods of love and hate.
#
# | Scenario        | E0 | J0 | a | b | c | d |
# |-----------------|---|---|---|---|---|---|
# | Water & Fire    | 0.0 | 1.0 | 0.3 | 0.5 | -0.5 | -0.3 |
#
# where `E0` and `J0` are the initial values. This means that _initially_ JD likes Elliot, but she is indifferent to his affection.
#
# &#9989;&nbsp; **Task:** Complete the cell below by adding code that
#
# - calls `solve_ivp` with the correct parameters **(2 points)**.
# - plots $E$ and $J$ vs time in the **same plot**. Don't forget to label them. **(2 points)**
#
# **NOTE:** I already wrote code for the figure. You only need to plot the lines.
#
# Make sure to
#
# - Pack the initial conditions in the correct order **(2 points)**.
# - Pack the constants in the correct order **(2 points)**.
#
# If you have done things right you should get the following plot
#
# ![JD and Elliot](https://raw.githubusercontent.com/msu-cmse-courses/cmse801-supplemental/main/OtherFigs/plot.png)

# %%
# Parameter values to be used
tstart, tend = 0.0, 20.
nsteps = 100
time = np.linspace(tstart, tend, nsteps)

# Initial conditions
E0 = 0.0
J0 = 1.0

a = 0.3 
b = 0.5
c = -0.5
d = -0.3

# Start the figure
fig = plt.figure(figsize=(8,6))

# PUT YOUR CODE HERE
    
plt.grid(alpha = 0.3)
plt.legend()
plt.ylabel("Lovers")
plt.xlabel("Time")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Time')

# %%
### ANSWER

# Parameter values to be used
tstart, tend = 0.0, 20.
nsteps = 100
time = np.linspace(tstart, tend, nsteps)

# Initial conditions
E0 = 0.0
J0 = 1.0

a = 0.3 
b = 0.5
c = -0.5
d = -0.3

fig = plt.figure(figsize=(8,6))

sols = solve_ivp(love_eq, 
                 (tstart, tend), 
                 [E0, J0], 
                 t_eval=time,
                 args= [(a, b, c, d)])

plt.plot(sols.t, sols.y[0,:], label = "Elliot")  
plt.plot(sols.t, sols.y[1,:], label = "JD")
# 2 points: for each plot 
    # 0.5 correct inputs,
    # 0.5 label
    
plt.grid(alpha = 0.3)
plt.legend()
plt.ylabel("Lovers")
plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# ---
# <a id="part_3"></a>
#
# # Part 3: Analysis (8 points):
#
# ![JD](https://media.giphy.com/media/7SEOvVtOdtU2Y/giphy.gif)
#
# &#9989;&nbsp; **Task:** Knowing that positive values indicate **like** while negative values indicate **dislike**, answer the following questions
#
# 1. What are the values of $E$ and $J$ at time = 2.5? **(2 points)**
# 2. What does it mean when the blue line increase ? **(1 point)**
# 3. What does it mean when the orange line decreases ? **(1 point)**
# 4. Do you notice a pattern? Explain. **(2 points)**
# 5. Is there a time in which both JD and Elliot like each other? Explain **(2 points)**
#
# **NOTE:** You can still answer these questions if you can't get the part above to work. Just look at the plot I show in Part 2 or you can download it from D2L.

# %% [markdown]
# Put your answers here

# %% [markdown]
# ---
#
# # Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz 03, and upload it there.

# %% [markdown]
# ![Moira2](https://media.giphy.com/media/d1E2HnwywoTkES08/giphy.gif)

# %% [markdown]
# &#169; Copyright 2023,  Michigan State University Board of Trustees
