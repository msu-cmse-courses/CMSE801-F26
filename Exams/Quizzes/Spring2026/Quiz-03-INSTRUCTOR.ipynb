# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 801: Quiz 3 (Spring 2026)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, leverage generative AI tools etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. That said, **you should clearly cite all of the resources that you use to answer the questions on this quiz and indicated how you used them to arrive at your solution**.
#
# It should also be noted that **the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **19 points** possible on this quiz and each part of the quiz can be done independently. **If you get stuck _move on to another part of the quiz to earn some points there!_**

# %% [markdown]
# ### ANSWER (for making sure this gets removed) ###
#
# ## Template Guidelines
#
# **Learning Objectives from Homework 3:**
# - Using pandas to work with data and clean it
# - Make meaningful visual representations of the data
# - Solving ODEs numerically
#
# **Learning Objectives the Quiz will assess:**
# * Loading and manipulating (e.g. filtering, calculating basic statistics) data using Pandas
# * Visualizing data and models using matplotlib
# * Using a provided derivative function to solve an ODE numerically using `solve_ivp`
#
# **Learning objectives that we don't have time/space for**:
#
# * None
#
# **Quiz Duration:** 30 minutes (ideally, time can be extended slightly if needed)
# * This means your TA should be able to complete the quiz in at most 10 minutes (if TA completion time is closer to 15, consider extending quiz to 40 minutes)
#
# **Notes:**
# * The structure and rubric provided here is a suggestion and an example of the difficulty level expected. However, as long as your quiz assesses the learning objectives listed under "Learning Objectives the Quiz will assess" section above, you can differ from this structure. If you aren't sure that your quiz does that, run it by another instructor (lead isntructor, other faculty or TA)
# * The examples provided are examples and **should not be used directly without changes in any quizzes**
# * These quizzes are important for students to assess how well they understand the material independent of their groups, so when grading, be sure to provide feedback on where points were deducted. **You should also have a clear rubric with clearly stated point values, but you do not need to follow the point values included in this template**.
# * Quizzes should be written with ample time for TA to review! **Your TA should have at least 48 hours to review the quiz before it is given**.
# * Quizzes (and instructor solution with point-by-point rubrics) should be **pushed to the GitHub repo for record-keeping**.
#
# **Overall Structure:**
#
# 1. A section that focuses on assessing if students correctly load a CSV file using Pandas and then explores if they have mastered the ability to mask data for the purposes of filtering the data and can calculate basic statistical values.
# 2. A section that provides the students with a second ODEs and the derivative function needed to solve it. The students should be able to solve the ODE numerically using `solve_ivp` and plot the solution.

# %% [markdown]
# ---
#
# ## **1. Loading, exploring, and masking data with Pandas (6 points)**
#
# As you might be aware, MSU is big into college sports and a lot of folks were excited to see how well MSU does this football season. Not being a huge sports fan yourself, you starting thinking more about the MSU fight song and wondering how our fight song compares to that of other universities. Luckily, the website FiveThirtyEight happens to have a [dataset with all of this information](https://github.com/fivethirtyeight/data/tree/master/fight-songs)!
#
# &#9989;&nbsp; **Part 1.1 (2 points)**
#
# Load the `fight-songs.csv` file provided on D2L **using Pandas** and display the first 10 rows.

# %%
# Let's make sure pandas is imported
import pandas as pd

# Put your code here

# %%
### ANSWER
import pandas as pd

fs = pd.read_csv("fight-songs.csv")
fs.head(10)

# 1 point for loading the data
# 1 point for displaying the first 10 rows
# Out:
#            school   conference              song_name  \
# 0      Notre Dame  Independent          Victory March
# 1          Baylor       Big 12              Old Fight
# 2      Iowa State       Big 12      Iowa State Fights
# 3          Kansas       Big 12          I'm a Jayhawk
# 4    Kansas State       Big 12        Wildcat Victory
# 5        Oklahoma       Big 12          Boomer Sooner
# 6  Oklahoma State       Big 12       Ride 'Em Cowboys
# 7           Texas       Big 12            Texas Fight
# 8             TCU       Big 12         TCU Fight Song
# 9      Texas Tech       Big 12  Fight, Raiders, Fight
#
#                                              writers  year student_writer  \
# 0                   Michael J. Shea and John F. Shea  1908             No
# 1                         Dick Baker and Frank Boggs  1947            Yes
# 2  Jack Barker, Manly Rice, Paul Gnam, Rosalind K...  1930            Yes
# ...

# %% [markdown]
# &#9989;&nbsp; **Part 1.2 (2 points)**
#
# While you could look at the whole dataset and explore some of the similarities and differences, you're mainly curious about the universities that are part of the Big Ten conference.
#
# Create a mask that filters the data to show only the rows that match `'Big Ten'` in the "**conference**" column and store this filtered data in a **new dataframe**.
#
# **Display that dataframe once you've created it**, to confirm that you did it correctly.
#
# **Note**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** appropriately mask the data for partial credit. Also, if you can't figure out how to create the appropriate mask, but can figure out another way to achieve the same outcome, you can receive partial credit.

# %%
# Put your code here

# %%
### ANSWER

big_ten = fs[fs["conference"] == "Big Ten"]
big_ten

# 1 point for filtering the data in any way
# 1 point for using a mask to filter the data
# Out:
#             school conference             song_name  \
# 11        Illinois    Big Ten         Oskee-Wow-Wow
# 12         Indiana    Big Ten  Indiana, Our Indiana
# 13            Iowa    Big Ten       Iowa Fight Song
# 14        Maryland    Big Ten   Maryland Fight Song
# 15        Michigan    Big Ten           The Victors
# 16  Michigan State    Big Ten       Victory for MSU
# 17       Minnesota    Big Ten  The Minnesota Rouser
# 18        Nebraska    Big Ten  Dear Old Nebraska U.
# 19    Northwestern    Big Ten    Go! U Northwestern
# 20      Ohio State    Big Ten    Buckeye Battle Cry
# 21      Penn State    Big Ten       Fight On, State
# 22          Purdue    Big Ten           Hail Purdue
# 23         Rutgers    Big Ten   The Bells Must Ring
# 24       Wisconsin    Big Ten         On, Wisconsin
#
#                                        writers  year student_writer  \
# 11                    H.R. Green and H.V. Hill  1910            Yes
# ...

# %% [markdown]
# &#9989;&nbsp; **Part 1.3 (2 points)**
#
# Finally, you're curious about the average length of a Big Ten fight song, so you decide to look at the **mean** of the `sec_duration` column, which provides the length of the songs in seconds. **Write some code to calculate and display the mean** for the length of the songs.
#
# **Note #1**: there's more than one way you could do this.
#
# **Note #2**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** calculate and display the mean for partial credit.

# %%
# Put your code here

# %% [markdown]
# **What was the result?** From the output of your code, what is the mean for the duration of the songs? Record the number in the markdown cell below.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here*

# %%
### ANSWER
# Using "describe"
big_ten['sec_duration'].describe()
# Technically they could call describe on the full dataframe, but this is more explicit
# Either option is fine
# Out:
# count     14.000000
# mean      82.857143
# std       25.111619
# min       56.000000
# 25%       60.750000
# 50%       77.500000
# 75%       92.750000
# max      134.000000
# Name: sec_duration, dtype: float64

# %%
### ANSWER
# Using "mean" from numpy
import numpy as np
print(np.mean(big_ten['sec_duration']))

# 1 point for using describe or mean to get the average duration
# 1 point stating the result in the markdown cell
# Out:
# 82.85714285714286

# %% [markdown]
# ### ANSWER
#
# The mean is 82.86 seconds.

# %% [markdown]
# ---
# ## **2. Modeling a system using `solve_ivp` (13 points)**
#
# &#9989;&nbsp;  **Question 2.1 (4 points)**: In this question, you're going return to the model for how the biomass in a forest changes as a function of time. Again, we'll be thinking about how biomass moves between living trees, dead trees, and humus, which is defined to be "the organic component of soil, formed by the decomposition of leaves and other plant material by soil microorganisms."
#
# As before, we can model this system with the following equations (though note that the rate coefficients have been modified):
#
# $$ \frac{dx}{dt} = -x + 1.4y $$
# $$ \frac{dy}{dt} = -1.4y + 2.6z $$
# $$ \frac{dz}{dt} = -2.6z $$
#
# where $x$ is the biomass that has decayed in humus, $y$ is the biomass in dead trees, and $z$ is the biomass in living trees. Given that we're talking about the life and death of trees, we assume will use **decades** (10s of years) as our unit of time, $t$. This means that, for example, $t = 2$ would be _20 years_.
#
# Previously, you defined the derivatives function necessary to evolve this model, so now you're going to actually evolve the model using `solve_ivp` to evolve this model.
#
# In the code cell below, **you are provided with a correct derivatives function for this model.**
#
# Your task is to **solve this biomass system using `solve_ivp`**, assuming the following initial conditions:
#
# * $x(0) = 0$
# * $y(0) = 0$
# * $z(0) = 809601$ in units of thousands of tons (based on 2012 data for forests in Michigan).
#
# **Evolve the model for 5 decades (50 years) using a timestep of $\Delta t = 0.01$ decades.**
#
# **Code you need to write to solve this problem**:
# * A set of variables for storing your initial conditions, $x_0$, $y_0$, and $z_0$, set to the correct initial values.
# * A variable that stores all the times for which you want to solve the system of ODEs, you can generate these times using `np.arange()`. The times should match the time range and timestep size specified above.
# * Code that calls `solve_ivp` using all of the appropriate arguments and stores the result.
# * Code that unpacks the solution so that you can plot it.
#
# **Note**: you will not need the "`args`" argument for `solve_ivp` for this case because any model parameters that might be needed for this system are provided directly as numbers in the set of  ODEs include above.

# %%
#  DO NOT MODIFY THIS CELL -- Make sure to run this cell before you run the next cell though!

# These are the modules to need to import for this problem
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt

# This is the provide derivatives function for the ODE you're solving
def derivs(t, vals):
    x, y, z = vals
    dxdt = -x + 1.4*y
    dydt = -1.4*y + 2.6*z
    dzdt = -2.6*z
    return dxdt, dydt, dzdt

# %%
### Put your code here ###

# Define your initial conditions


# Define the time points you want to solve the ODE at


# Solve the ODE using solve_ivp


# Unpack the solution

# %%
### ANSWER

# Define your initial conditions
x0 = 0
y0 = 0
z0 = 809601
ICs = [x0, y0, z0]

# Define the time points you want to solve the ODE at
t = np.arange(0, 5, 0.01)

# Solve the ODE using solve_ivp
sol = solve_ivp(derivs, (t[0], t[-1]),ICs, t_eval=t)

# Unpack the solution
x = sol.y[0,:]
y = sol.y[1,:]
z = sol.y[2,:]
#print(x)

# Grading
# 1 point for defining the initial conditions correctly
# 1 point for defining the time points correctly
# 1 point for solving the ODE correctly using solve_ivp
# 1 point for unpacking the solution correctly

# %% [markdown]
# &#9989;&nbsp; **Question 2.2 (4 points)**: Now that you have a solution to the model, make a single plot that displays the evolution of all three variables, humus, dead trees, and living trees as a function time. Each line should be a different color and your plot should contain a $x$-axis label, a $y$-axis label, and a legend.

# %%
### Put your code here ###

# %%
### ANSWER

plt.figure(1)
plt.plot(t*10,x,label="Humus")
plt.plot(t*10,y,label="Dead Trees")
plt.plot(t*10,z,label="Living Trees")
plt.xlabel("Time in years")
plt.ylabel("Biomass")
plt.legend()

# Grading
# 1 point for each line (3 points total)
# 1 point for labeling and legend

# %% [markdown]
# &#9989;&nbsp; **Question 2.3 (3 points)**: Make a second plot where you zoom in on just the first two decades of the evolution of the system. Ensure that all of the same labels are included. **Note**: This should not involve re-running your model, but instead should involve plotting a subset of all of the values using NumPy array indexing. Partial credit will be given you cannot figure out how to use array indexing and choose to re-run the model for less time.

# %%
#### Put your code here ###

# %%
### ANSWER

stop_index = int(len(t) * 0.4)

plt.figure(1)
plt.plot(t[0:stop_index]*10,x[0:stop_index],label="Humus")
plt.plot(t[0:stop_index]*10,y[0:stop_index],label="Dead Trees")
plt.plot(t[0:stop_index]*10,z[0:stop_index],label="Living Trees")
plt.xlabel("Time (years)")
plt.ylabel("Biomass")
plt.grid()
plt.legend()

# Grading
# 1 point for plotting the three lines again
# 1 point for figuring out how to slice the data
# 1 point for labeling and legend

# %% [markdown]
# &#9989;&nbsp; **Question 2.4 (1 point)**: At approximately what point in time is the total amount of living trees half of the starting value? Explain how you determined this. Feel free to include code, if you wish (code is not required).

# %% [markdown]
# *Put your answer here*

# %%
# Put any code you care to here

# %% [markdown]
# ### ANSWER
# ~2.5 years

# %% [markdown]
# &#9989;&nbsp; **Question 2.5 (1 point)**: At approximately what point in time does the total amount of biomass in the humus exceed that of the dead trees? Explain how you determined this. Feel free to include code, if you wish (code is not required).

# %% [markdown]
# *Put your answer here*

# %%
# Put any code you care to here

# %% [markdown]
# ### ANSWER
# ~10 years

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.
