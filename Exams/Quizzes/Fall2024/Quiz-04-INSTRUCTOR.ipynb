# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 801: Quiz 4 (Fall 2024)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, leverage generative AI tools etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. That said, **you should clearly cite all of the resources that you use to answer the questions on this quiz and indicated how you used them to arrive at your solution**.
#
# It should also be noted that **the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **14 points** possible on this quiz.

# %% [markdown]
# ### ANSWER (for making sure this gets removed) ###
#
# ## Template Guidelines
#
# **Learning Objectives from Homework 4:**
# - Make meaningful visual representations of the data
# - Fitting curves to data and evaluating model fit
#
# **Learning Objectives the Quiz will assess:**
# * Using curve_fit to fit models to data and find best fit model parameters
# * Using best fit parameters to calculate expected model values
# * Visualizing data and models using matplotlib
#
# **Learning objectives that we don't have time/space for**:
#
# * Nones
#
# **Quiz Duration:** 30 minutes (ideally, time can be extended slightly if needed)
# * This means your TA should be able to complete the quiz in at most 10 minutes (if TA completion time is closer to 15, consider extending quiz to 40 minutes)
#
# **Notes:**
# * The structure and rubric provided here is a suggestion and an example of the difficulty level expected. However, as long as your quiz assesses the learning objectives listed under "Learning Objectives the Quiz will assess" section above, you can differ from this structure. If you aren't sure that your quiz does that, run it by another instructor (or your TA)
# * The examples provided are examples and **should not be used directly without changes in any quizzes**
# * These quizzes are important for students to assess how well they understand the material independent of their groups, so when grading, be sure to provide feedback on where points were deducted. **You should also have a clear rubric with clearly stated point values, but you do not need to follow the point values included in this template**.
# * Quizzes should be written with ample time for TA to review! **Your TA should have at least 48 hours to review the quiz before it is given**.
# * Quizzes (and instructor solution with point-by-point rubrics) should be **pushed to the GitHub repo for record-keeping**.
#
# **Overall Structure:**
#
# 1. A section that uses some provided data (so as not to penalize them again for not having mastered loading data) and a model function to find the best fit parameters for the model using curve_fit. This question should also assess if they can use those best fit parameters to produce the expected model values and then use matplotlib to visualize their model and compare it to the data.

# %% [markdown]
# ---
# # 1. Fitting a model to data with `curve_fit` and visualizing the results (14 points)
#
# The friend who was bugging you back on Quiz 2 has returned to you for help with their climate modeling class.
#
# This time, **they want to see if their temperature model can be used to fit real data**.
#
# As before, they've provided you with their temperature model function which takes in a list of times (in days) and four model parameters, `A`, `B`, `C`, and `D`, and uses those to calculate temperature values.
#
# They've also provided you with a downsampled set of the 2018 temperature data (which they saved as a **JSON** file), so that you can you try fitting their model to the data. The file is provided with this exam and is called `temps_2018_downsampled.json`.
#
# Your task is to **use the provided function and the `curve_fit` function from scipy to find the best fit parameters when the model is applied to the 2018 temperature data you looked at previously**.
# <br><br><br>
# &#9989;&nbsp; **Part 1.1 (2 points)** Before moving on **make sure you load the data and display it in the cell below** (You'll need to look up what method in Pandas can load a JSON file. If you cannot figure out how to do this, ask an instructor and we'll point you in the right direction with a loss of the points for this section).

# %%
# You can use pandas to load JSON data file, so we'll import it here
import pandas as pd

# Put your code to load the JSON data file here

# %%
### ANSWER
temperature_data = pd.read_json('temps_2018_downsampled.json')
temperature_data

# %%
### ANSWER (for subsampling the original data to generate the json data
temp_data = pd.read_csv('temps_2018.csv')
down_sampled = temp_data.iloc[::3]
down_sampled.to_json('temps_2018_downsampled.json', orient='records')

# %%
### ANSWER
from io import StringIO

# Previous version of this quiz used the following embedded JSON data
temperature_data = pd.read_json(StringIO('[{"days":1.0,"TMAX":12},{"days":4.0,"TMAX":14},{"days":7.0,"TMAX":31},{"days":10.0,"TMAX":50},{"days":13.0,"TMAX":16},{"days":16.0,"TMAX":17},{"days":19.0,"TMAX":37},{"days":22.0,"TMAX":51},{"days":25.0,"TMAX":35},{"days":28.0,"TMAX":43},{"days":31.0,"TMAX":41},{"days":34.0,"TMAX":34},{"days":37.0,"TMAX":22},{"days":40.0,"TMAX":21},{"days":43.0,"TMAX":26},{"days":46.0,"TMAX":46},{"days":49.0,"TMAX":38},{"days":52.0,"TMAX":48},{"days":55.0,"TMAX":43},{"days":58.0,"TMAX":60},{"days":61.0,"TMAX":44},{"days":64.0,"TMAX":39},{"days":67.0,"TMAX":31},{"days":70.0,"TMAX":38},{"days":73.0,"TMAX":39},{"days":76.0,"TMAX":48},{"days":79.0,"TMAX":40},{"days":82.0,"TMAX":44},{"days":85.0,"TMAX":53},{"days":88.0,"TMAX":46},{"days":91.0,"TMAX":37},{"days":94.0,"TMAX":33},{"days":97.0,"TMAX":32},{"days":100.0,"TMAX":45},{"days":103.0,"TMAX":58},{"days":106.0,"TMAX":37},{"days":109.0,"TMAX":54},{"days":112.0,"TMAX":64},{"days":115.0,"TMAX":59},{"days":118.0,"TMAX":54},{"days":121.0,"TMAX":83},{"days":124.0,"TMAX":72},{"days":127.0,"TMAX":69},{"days":130.0,"TMAX":67},{"days":133.0,"TMAX":64},{"days":136.0,"TMAX":79},{"days":139.0,"TMAX":70},{"days":142.0,"TMAX":63},{"days":145.0,"TMAX":88},{"days":148.0,"TMAX":93},{"days":151.0,"TMAX":87},{"days":154.0,"TMAX":72},{"days":157.0,"TMAX":72},{"days":160.0,"TMAX":69},{"days":163.0,"TMAX":78},{"days":166.0,"TMAX":82},{"days":169.0,"TMAX":91},{"days":172.0,"TMAX":80},{"days":175.0,"TMAX":75},{"days":178.0,"TMAX":76},{"days":181.0,"TMAX":94},{"days":184.0,"TMAX":91},{"days":187.0,"TMAX":78},{"days":190.0,"TMAX":90},{"days":193.0,"TMAX":87},{"days":196.0,"TMAX":92},{"days":199.0,"TMAX":81},{"days":202.0,"TMAX":77},{"days":205.0,"TMAX":84},{"days":208.0,"TMAX":78},{"days":211.0,"TMAX":84},{"days":214.0,"TMAX":86},{"days":217.0,"TMAX":95},{"days":220.0,"TMAX":84},{"days":223.0,"TMAX":87},{"days":226.0,"TMAX":89},{"days":229.0,"TMAX":78},{"days":232.0,"TMAX":80},{"days":235.0,"TMAX":80},{"days":238.0,"TMAX":85},{"days":241.0,"TMAX":79},{"days":244.0,"TMAX":81},{"days":247.0,"TMAX":89},{"days":250.0,"TMAX":69},{"days":253.0,"TMAX":66},{"days":256.0,"TMAX":78},{"days":259.0,"TMAX":86},{"days":262.0,"TMAX":79},{"days":265.0,"TMAX":66},{"days":268.0,"TMAX":79},{"days":271.0,"TMAX":60},{"days":274.0,"TMAX":58},{"days":277.0,"TMAX":78},{"days":280.0,"TMAX":57},{"days":283.0,"TMAX":75},{"days":286.0,"TMAX":53},{"days":289.0,"TMAX":55},{"days":292.0,"TMAX":55},{"days":295.0,"TMAX":58},{"days":298.0,"TMAX":49},{"days":301.0,"TMAX":46},{"days":304.0,"TMAX":56},{"days":307.0,"TMAX":47},{"days":310.0,"TMAX":53},{"days":313.0,"TMAX":36},{"days":316.0,"TMAX":39},{"days":319.0,"TMAX":33},{"days":322.0,"TMAX":37},{"days":325.0,"TMAX":34},{"days":328.0,"TMAX":47},{"days":331.0,"TMAX":29},{"days":334.0,"TMAX":38},{"days":337.0,"TMAX":38},{"days":340.0,"TMAX":31},{"days":343.0,"TMAX":32},{"days":346.0,"TMAX":40},{"days":349.0,"TMAX":36},{"days":352.0,"TMAX":36},{"days":355.0,"TMAX":40},{"days":358.0,"TMAX":33},{"days":361.0,"TMAX":50},{"days":364.0,"TMAX":32}]'))

# %% [markdown]
# &#9989;&nbsp; **Part 1.2 (6 points)**
#
# Now that you have a dataset loaded, **use the following provided function, `calculate_temperature`, and `curve_fit` to find the best fit values for the parameters, $A$, $B$, $C$, and $D$**. Since your friend has already been experimenting with the model, make sure you give `curve_fit` a good starting point for finding the best fit parameters using the `p0` argument and these starting values:
# * A = 27.5
# * B = 0.017
# * C = 215
# * D = 57.5
#
# Once you've found the best values, **print them out**. You should find that they are not far off from, but not the same as, the original values that your friend gave you.
#
# Make sure to execute the next cell so that you have the necessary modules and the calculate_temperature function available in your notebook.

# %%
# Will need to use NumPy for the function
import numpy as np

# Will need to import curve_fit from SciPy
from scipy.optimize import curve_fit

# This function calculates temperature over a range of days
def calculate_temperature(t, A, B, C, D):
     return A*np.cos(B*(t - C)) + D

# %%
# Put your code here

# %%
### ANSWER
best_fit_params, covariance = curve_fit(calculate_temperature, temp_data['days'], temp_data['TMAX'], p0=(27.5,0.017,215,57.5))
for p in best_fit_params:
    print('%.3f' % p)

# 2 points for calling curve_fit with the correct minimum arguments
# 1 point for using the p0 argument in curve_fit
# 1 point for printing the correct values for A, B, C, and D
# 2 "freebie" points just for trying

# %% [markdown]
# &#9989;&nbsp; **Part 1.3 (6 points)**
#
# Now that you have a set of best fit parameters, **use those parameters to calculate the expected model values and plot the expected model values on top of the actual data values**. Make sure to label your axes and include a legend to communicate what parts of the plot correspond to the model versus the data.

# %%
# Make sure we import matplotlib
import matplotlib.pyplot as plt

# Put your code here

# %%
### ANSWER
import matplotlib.pyplot as plt
plt.plot(temp_data['days'], temp_data['TMAX'], 'o', label='Data')
plt.plot(temp_data['days'], calculate_temperature(temp_data['days'], best_fit_params[0], best_fit_params[1], best_fit_params[2], best_fit_params[3]), label='Best Fit', lw=3)
plt.xlabel('Days')
plt.ylabel('Temperature (F)')
plt.legend();

# 1 point for plotting the data
# 2 points for plotting the best fit by calling calculate_temperature with the best fit parameters
# 1 point for labeling the x-axis
# 1 point for labeling the y-axis
# 1 point for adding a legend

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #4, and upload it there.
