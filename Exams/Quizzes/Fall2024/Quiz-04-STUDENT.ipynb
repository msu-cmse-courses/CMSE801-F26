# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 801: Quiz 4 (Fall 2024)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, leverage generative AI tools etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. That said, **you should clearly cite all of the resources that you use to answer the questions on this quiz and indicated how you used them to arrive at your solution**.
#
# It should also be noted that **the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **14 points** possible on this quiz.

# %% [markdown]
# ---
# # 1. Fitting a model to data with `curve_fit` and visualizing the results (14 points)
#
# The friend who was bugging you back on Quiz 2 has returned to you for help with their climate modeling class.
#
# This time, **they want to see if their temperature model can be used to fit real data**.
#
# As before, they've provided you with their temperature model function which takes in a list of times (in days) and four model parameters, `A`, `B`, `C`, and `D`, and uses those to calculate temperature values.
#
# They've also provided you with a downsampled set of the 2018 temperature data (which they saved as a **JSON** file), so that you can you try fitting their model to the data. The file is provided with this exam and is called `temps_2018_downsampled.json`.
#
# Your task is to **use the provided function and the `curve_fit` function from scipy to find the best fit parameters when the model is applied to the 2018 temperature data you looked at previously**.
# <br><br><br>
# &#9989;&nbsp; **Part 1.1 (2 points)** Before moving on **make sure you load the data and display it in the cell below** (You'll need to look up what method in Pandas can load a JSON file. If you cannot figure out how to do this, ask an instructor and we'll point you in the right direction with a loss of the points for this section).

# %%
# You can use pandas to load JSON data file, so we'll import it here
import pandas as pd

# Put your code to load the JSON data file here

# %% [markdown]
# &#9989;&nbsp; **Part 1.2 (6 points)**
#
# Now that you have a dataset loaded, **use the following provided function, `calculate_temperature`, and `curve_fit` to find the best fit values for the parameters, $A$, $B$, $C$, and $D$**. Since your friend has already been experimenting with the model, make sure you give `curve_fit` a good starting point for finding the best fit parameters using the `p0` argument and these starting values:
# * A = 27.5
# * B = 0.017
# * C = 215
# * D = 57.5
#
# Once you've found the best values, **print them out**. You should find that they are not far off from, but not the same as, the original values that your friend gave you.
#
# Make sure to execute the next cell so that you have the necessary modules and the calculate_temperature function available in your notebook.

# %%
# Will need to use NumPy for the function
import numpy as np

# Will need to import curve_fit from SciPy
from scipy.optimize import curve_fit

# This function calculates temperature over a range of days
def calculate_temperature(t, A, B, C, D):
     return A*np.cos(B*(t - C)) + D

# %%
# Put your code here

# %% [markdown]
# &#9989;&nbsp; **Part 1.3 (6 points)**
#
# Now that you have a set of best fit parameters, **use those parameters to calculate the expected model values and plot the expected model values on top of the actual data values**. Make sure to label your axes and include a legend to communicate what parts of the plot correspond to the model versus the data.

# %%
# Make sure we import matplotlib
import matplotlib.pyplot as plt

# Put your code here

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #4, and upload it there.
