# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 801: Quiz 1 (Fall 2024)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, leverage generative AI tools etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. That said, **you should clearly cite all of the resources that you use to answer the questions on this quiz and indicated how you used them to arrive at your solution**.
#
# It should also be noted that **the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **32 points** possible on this quiz and each part of the quiz can be done independently. **If you get stuck _move on to another part of the quiz to earn some points there!_**

# %% [markdown]
# ### ANSWER (for making sure this gets removed) ###
#
# ## Template Guidelines
#
# **Learning Objectives from Assignments:**
# * Work with number, string, and list data types
# * Learn how to do order of magnitude approximations
# * Write for and while loops
# * Combine lists and loops to compute new values
# * Use python lists to store values
# * Use loops to iterate over a specified range, over a list of values, or until a condition is met
# * Use conditional statements to control code flow
# * Define and use functions to organize and reuse code
# * Basic debugging
#
# **Learning Objectives the Quiz will assess:**
# * When should students use a For loop vs. while loop
# * What problems can we solve with Loop by index vs. loop by value
# * Calculating and Storing values in lists (within loops)
# * Writing a simple function and using it
# * Basic debugging (potentially involving: lists, loops, variables; **this was an implicit learning goal that we didn't work on to explicitly, so don't get carried away with this one**)
#
# **Learning objectives that we don't have time/space for**:
#
# * Using conditional statements, we can try to integrate this into a future quiz.
#
# **Quiz Duration:** 30 minutes
# * This means the TA should be able to complete the quiz in at most 10 minutes
#
# **Notes:**
# * The structure and rubric provided here is a suggestion and an example of the difficulty level expected. However, as long as your quiz assesses the learning objectives listed under "Learning Objectives the Quiz will assess" section above, you can differ from this structure. If you aren't sure that your quiz does that, run it by another instructor (e.g. a former intructor or your TA)
# * The examples provided are examples and **should not be used directly without changes in any quizzes**
# * These quizzes are important for students to assess how well they understand the material independent of their groups, so when grading, be sure to provide feedback on where points were deducted. **You should also have a clear rubric with clearly stated point values, but you do not need to follow the point values included in this template**.
# * Quizzes should be written with ample time for your TA to review! **Your TA should have at least 48 hours to review the quiz before it is given**.
# * Quizzes (and instructor solution with point-by-point rubrics) should be **pushed to the GitHub repo for record-keeping**.
#
# **Overall Structure:**
#
# * Basic question about a list (and indexing)
# * Question that probes students knowledge an ability to use `for` loop by index vs. by value and an opportunity to do some debugging
# * Question with a `while` loop that has them take an awkward `for` loop and rewrite it as a `while` loop
# * Question that requires them to write a function and use it to ensure it works

# %% [markdown]
# ---
# # 1. Lists and Indexing (6 points)
#
# In the cell below, define a list that holds the names of at least 5 colors, but make it so that the first color in your list is `"red"`. Then, **using indices to access the values in your list**, write a print statement that prints your colors in **alphabetic order**. Note that for this problem, **you are not expected to sort the list or iterate through a loop**, but rather to access the values in the list in a way that they are printed in alphabetic order.

# %%
# put your code here

# %%
### ANSWER

my_colors = ["red", "black", "green", "blue", "orange"]

print(my_colors[3],my_colors[0],my_colors[2],my_colors[4],my_colors[0])

# 1 points for defining a list
# 1 points for containing at least 5 colors as strings with "red" first
#    (0.5 points if the list doesn't put red in the right spot)
# 2 points for using the indices in the print statement
# 2 points for putting the colors in the correct alphabetical order

# %% [markdown]
# ---
#
# # 2. For Loops and Debugging: Calculating Enrollment Fractions (8 points)
#
# You work for a university, specifically helping them to figure out if they are meeting their enrollment goals in their undergraduate courses. For each course, the enrollment system stores three lists:
# - One with the name of the course
# - One with the total number of seats available in the course
# - One with the total number of students enrolled in the course

# %%
course_names = ["CMSE 201", "STT 180", "MTH 132", "CEM 142", "PHY 183", "IAH 201"]
course_seats = [60, 50, 100, 200, 120, 80]
course_enrollment = [57, 50, 84, 175, 108, 66]

# %% [markdown]
# **Your university needs a piece of code that will calculate the fraction of total seats available in a course that have been filled by enrolled students, so they know if they can still enroll more students in each course.** To calculate the fraction of seats filled *for one course*, the course's current enrollment must be divided by the total number of seats available.
#
# For example, the fraction filled for CMSE 201 is:
#
# > 57 students enrolled $\div$  60 seats available $=$ 0.95
#
# If the resulting fraction is 1.0, then they know the course is full.
#
# Your boss started to write this bit of code (below), but part way through they **ran into an error** they couldn’t figure out.

# %%
### DO NOT MODIFY THIS CELL ###
enrollment_fractions = []

for jj in range(len(course_seats)):
    fraction = course_enrollment[ii]/course_seats[jj]
    enrollment_fractions.append(fraction)
print(enrollment_fractions)

# %% [markdown]
# \
# &#9989;&nbsp; **Part 1 (4 points):** In the cell below, describe the bug in the code and how you would (or did) solve it. Specifically, provide the following information:
# 1. The line of code that caused the error(s)
# 2. The type of error it is (i.e. the error code provided by Python)
# 3. A plain english description of the error(s) in the code
# 4. How you would solve or did solve the error(s)

# %% [markdown]
# <font size=6 color="green">&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# 1. **(1 Points)** Line 5 (`fraction = course_enrollment[ii]/course_seats[jj]`) threw the error
# 1. **(1 Points)** NameError: name 'ii' is not defined
# 1. **(1 Points)** The appropriate index variable in our loop for both lists is `jj`, but `course_enrollment` was being indexed with `ii`
# 1. **(1 Points)** We need to replace `ii` with `jj` to correctly index the course_enrollment list

# %% [markdown]
# &#9989;&nbsp; **Part 2 (2 points):** In the empty code cell below, copy and paste the code from above and rewrite the buggy code so that it works properly.

# %%
# Put your modified code here

# %%
#### ANSWER ###

#Basically full points (2) for getting it running. 1 point for trying to modify the code, but failing to get it working.

enrollment_fractions = []

for jj in range(len(course_seats)):
    fraction = course_enrollment[jj]/course_seats[jj]
    enrollment_fractions.append(fraction)
print(enrollment_fractions)

# %% [markdown]
# &#9989;&nbsp; **Part 3 (2 points):** Is this code "looping by index" or "looping by value"? Do you think you could you solve the problem using the other kind of `for` loop? Why or why not?

# %% [markdown]
# <font size=6 color="green">&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# - **(1 Points)** It is looping by index.
# - **(1 Points)** No we couldn't solve this problem by looping by value, since we need to access two lists (unless we used the `enumerate` function).

# %% [markdown]
# ---
# # 3. While Loops (10 points)
#
# In the cell below, there is a `for` loop and some lists that your friend wrote to keep track of the amount of money they spent on the items they bought for brunch this weekend. When they gave you their code, you argued that you could have accomplished the same thing using a `while` loop instead. They weren't convinced that was true and told you to prove it. *You need to convince them you were right!*
#
# In the empty cell below, rewrite the `for` loop as a `while` loop. The output should remain the same, but you can change any of the variable names as needed.
#
# Finally, respond to the following question in markdown cell below: **What was (or, if you didn't have time to get it working, would be) your strategy or thought process for converting the for loop to the while loop?**

# %%
### DO NOT MODIFY THIS CELL ###
brunch_items = ['coffee','donuts','cereal','juice','bagels','fruit','bacon','eggs','granola','yogurt']
item_cost = [20,30,4,8,24,10,12,5,6,9]

count = 0
total_cost = 0
for i in brunch_items:
    print('I spent',item_cost[count],'dollars on',brunch_items[count])
    total_cost += item_cost[count]
    count = count + 1
print('I spent a total of',total_cost,'dollars on brunch.')

# %%
# Put your rewritten code here

# %% [markdown]
# <font size=6 color="green">&#9998;</font> *Put your strategy/thought process for converting the `for` loop to a `while` loop here.*

# %%
### ANSWER
# One possible solution

# Full credit for the code (8 points) for any while loop that runs while maintaining the same output
# Partial credit:
#    - 4 points for a while loop that runs but does not keep the same output
#    - 2 points for as properly formatted "while" line, even if the rest of the code doesn't work
#    - 2 points if their "while" condition wasn't right, but they correctly implemented the counter variable
# 
# 2 points for a reasonable thought process/strategy that conveys that they need to run a counter
# that counts up until it reaches the length of the list and that they need to increment that counter in the loop

count = 0
total_cost = 0
while count < len(brunch_items):
    print('I spent',item_cost[count],'dollars on',brunch_items[count])
    total_cost += item_cost[count]
    count = count + 1
print('I spent a total of',total_cost,'dollars on brunch.')

# %% [markdown]
# ---
#
# # 4. Writing a function (8 points)
#
# The other day you met up with some friends for dinner and when it came time to pay the tab, there were a lot of disgreements about how much each person owed. You finally got it figured out, but later that night, while working on your CMSE 801 homework, you realized that you could probably write a python function to avoid this situation in the future!
#
# **Write a function**, using whatever function name you want, that takes the following arguments:
# * the total dollar amount of the tab for your group
# * the percentage you plan to pay for the tip (as a number between 0 and 1, so 15% would be given as `0.15`)
# * the number of people in your group. Make it so that this argument has a default value of 4.
#
# Your function should take the total amount of the tab, add on the amount for the tip, and then divide the tab+tip by the number of people in your group to determine the amount that each person owes. **Your function should return the amount that each person owes.**
#
# **Test that your function is working correctly**, by giving it:
# * a total tab of 108.20 dollars
# * a 20\% tip
# * a group of 8 people
#
# If it is working correctly, you should get that each person owes \$16.23.
#
# Then, **check if your default value is working**, and give it just the total tab of 108.20 dollars and a 20\% tip (without a group size) and see if it returns \$32.46 for the amount owed per person (which would be for 4 people).

# %%
# Write your function here

# %%
# Test your function here to make sure it works
# Make sure to run both of the tests mentioned above

# %%
### ANSWER

def split_tab(total, tip, group_size=4):
    tab_with_tip = total * (1+tip)
    return tab_with_tip/group_size

print(split_tab(108.20, 0.2, 8))
print(split_tab(108.20, 0.2))

# 1 point for correctly defining a function using a function name of their choosing
# 1 point for providing the correct function arguments
# 1 point for correctly setting the default for group size
# 1 point for correctly adding in the tip
# 1 point for correctly dividing by the number of people
# 1 point for return that amount owed per person
# 1 point for testing the function to demonstrate that it is working correctly.
# 1 point for testing the function using the default group size

# If the student doesn't correctly pass the values in and somehow hard codes
# them or defines them outside the function, even if they get the right values, the maximum number of points is 6

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
