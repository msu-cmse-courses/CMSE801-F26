# %% [markdown]
# <img src="https://cmse.msu.edu/_assets/images/about/image001.png"
#      alt="CMSE Logo"
#      align="right"
#      height="400"
#      width="400" />
# # <font color=18453B>CMSE 801 - Day 23</font>
# ## Project draft presentations
# ### November 20, 2024

# %% [markdown]
# ## General Course Announcements
#
# * Final version of your project notebook is due **December 1 by 11:59pm**.
#     * We will assign presentation days on **Monday (11/25)** using a random number generator. **Contact me if you have a conflict with either of the two presentation days (December 2 and December 4).** We will be meeting in EB 1502/3 (CMSE conference room)
#         * Some of our presentations will extend beyond the normal class ending time, if you cannot stick around past 9:50am, please let me know that as well.
#     * Your presentation will be **strictly limited to 4 minutes**.
#     * You will be getting project credit for observing and rating your peers, so you are expected to attend both presentation days.
# * You can continue to work on your slides after that deadline and up until you present.
# * Quiz 4 will take place **today**.

# %% [markdown]
# ## Questions/comments from Day 23 PCA
#
# * Lots of effort being made on moving your projects forward
# * Some unexpected obstacles have come up

# %% [markdown]
# ## Plans for today
#
# * Present your slides to your group members
#     * **Step 1**: present for ~4 minutes
#     * **Step 2**: Give group members a minute or 2 to record their feedback
#     * **Step 3**: Receive feedback from peers
#         * Try to record this feedback or ask your group members to send them their feedback via Teams or email.
# * Work on your project using your group feedback and the review the project expectations on the website to make sure you're meeting the requirements for the project.
#     * This is a great time to ask us questions and get help on issues you may be running into!

# %% [markdown]
# ## Looking forward - Day 24 PCA: Do more with random numbers, setting up for the Traveling Salesperson
#
# * You'll explore more ways that random numbers can be used to solve problems (e.g. numerical integration)
# * You'll think about the traveling salesperson problem and try to right some functions that will be needed to solve that problem
