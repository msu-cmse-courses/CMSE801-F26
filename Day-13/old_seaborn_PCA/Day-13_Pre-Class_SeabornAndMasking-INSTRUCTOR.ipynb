# %% [markdown]
# # Day 13: Pre-class Assignment: Visualizing data with Seaborn and using masks in NumPy
#
# <img src="https://seaborn.pydata.org/_images/scatterplot_matrix.png" width=500px>

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# ## Goals for today's pre-class assignment
#
# * Use the seaborn module to visualize data
# * Practice using masks with NumPy arrays
#
# ## Assignment instructions
#
# **This assignment is due by 7:59 p.m. the day before class,** and should be uploaded into the appropriate "Pre-class assignments" submission folder.  If you run into issues with your code, make sure to use Slack to help each other out and receive some assistance from the instructors. Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ### Useful reference
#
# For this pre-class assignment, you may find parts of the seaborn tutorial page useful:
#
# * https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ---
# ## Part 1: Visualizing data with Seaborn
#
# When doing data science, visualizing your results can often be just as important as doing the analysis. Afterall, if you can't communicate your results effectively, what good was all the work that you did?
#
# Thus far in the course we've use standard matplotlib functions to visualize our results, but there is a handy package called Seaborn that tries to improve upon the basic aesthetics of matplotlib while also adding some specific functionality for doing statistical analysis of data.
#
# In this assignment, you're going to test out how to use seaborn to make plots and change the way they look.
#
# There first thing we need to do is import the `seaborn` module:

# %%
# Import matplotlib and make sure plots will show up in the notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# import seaborn  ("sns" is the commonly used variable name for seaborn)
import seaborn as sns

# %% [markdown]
# Of course, if we want to make some nice new visualizations, we need some data to plot. Let's revisit the Great Lakes data from a previous in-class assignment! However, instead of loading the .csv files with NumPy, let's use Pandas!

# %%
# import pandas
import pandas as pd

# Load up the Lake Ontario data
# (remember, you need to have a copy of the data in the same location as this notebook)
ont = pd.read_csv("ont.csv")
ont.head()
# Out:
#    Lake Ontario annual averages     AnnAvg  Unnamed: 2  \
# 0                          1860  75.046167         NaN
# 1                          1861  75.232917         NaN
# 2                          1862  75.238417         NaN
# 3                          1863  75.113833         NaN
# 4                          1864  75.044250         NaN
#
#                                           Unnamed: 3
# 0  1860-1917 levels are Oswego; 1918-present lake...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# Hmm, why do we have two "Unnamed" columns? Take a look at the original .csv file and determine why this is happening. Since carrying around columns that are full of "NaN"s isn't particularly useful, we're going to use Pandas to "drop" those columns and create a new dataframe that doesn't contain those columns:

# %%
# Drop the unnamed columns and store the new version of the dataframe
ont.drop(columns=["Unnamed: 2", "Unnamed: 3"], inplace=True)
ont.head()
# Out:
#    Lake Ontario annual averages     AnnAvg
# 0                          1860  75.046167
# 1                          1861  75.232917
# 2                          1862  75.238417
# 3                          1863  75.113833
# 4                          1864  75.044250

# %% [markdown]
# This looks much better!
#
# &#9989; **Do the same thing with the other lake files: `eri.csv`, `sup.csv`, and `mhu.csv`. Make sure the dataframes have all of the right information in them and no undesired columns.**
#
# **Note**: you might notice that the Lake Erie file is missing a column label and that you end up with one extra "Unnamed" column, but instead of being full of NaNs, it's the column with the actual lake levels. See if you can figure out how to rename the "Unnamed" column using the [`rename()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html) function. Remember that you need to store the new dataframe that is created by the `rename` function.

# %%
# Put your code here for reading in the other lake files using Pandas

# %%
### ANSWER ###
mhu = pd.read_csv("mhu.csv")
mhu = mhu.drop(columns=["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"])
mhu.head()
### ANSWER ###
# Out:
#    Michigan-Huron annual averages      AnnAvg
# 0                            1860  177.335167
# 1                            1861  177.331833
# 2                            1862  177.316000
# 3                            1863  177.179667
# 4                            1864  176.995583

# %%
### ANSWER ###
sup = pd.read_csv("sup.csv")
sup = sup.drop(columns=["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"])
sup.head()
### ANSWER ###
# Out:
#    Lake Superior annual averages      AnnAvg
# 0                           1860  183.397928
# 1                           1861  183.410761
# 2                           1862  183.324594
# 3                           1863  183.208593
# 4                           1864  183.149176

# %%
### ANSWER ###
eri = pd.read_csv("eri.csv")
eri = eri.drop(columns=["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"])
eri = eri.rename(columns={"Unnamed: 1": "AnnAvg"})
eri.head()
### ANSWER ###
# Out:
#    Lake Erie annual averages      AnnAvg
# 0                       1860  174.688483
# 1                       1861  174.712317
# 2                       1862  174.744983
# 3                       1863  174.655733
# 4                       1864  174.471567

# %% [markdown]
# ### Making seaborn plots
#
# Now that you have all the data loaded up, let's try making some of the same plots we made for the Great Lakes data in class.
#
# First, we'll make a plot of the Lake Ontario levels as a function of time:

# %%
sns.set()
plt.plot(ont['Lake Ontario annual averages'], ont['AnnAvg'])

# %% [markdown]
# You should get a plot that looks familiar but looks a bit different than a normal matplotlib plot.
#
#  &#9989; **Question**: What is the `sns.set()` line doing? You might want to refer to the seaborn documentation here: https://seaborn.pydata.org/tutorial/aesthetics.html. Note that the `set()` command only needs to be called once for the effect to be applied to all future plots.

# %% [markdown]
# *Put your answer here*

# %% [markdown]
# &#9989; **Task:** Add some axis labels to the plot and then make similar plots for each of the Lake data files.

# %%
# Put your code here and create new cells as necessary

# %%
### ANSWER ###
plt.plot(ont['Lake Ontario annual averages'], ont['AnnAvg'])
plt.xlabel("Time")
plt.ylabel("Lake Ontario levels")
### ANSWER ###
# Out:
# Text(0, 0.5, 'Lake Ontario levels')

# %%
### ANSWER ###
plt.plot(eri['Lake Erie annual averages'], eri['AnnAvg'], color="orange")
plt.xlabel("Time")
plt.ylabel("Lake Erie levels")
### ANSWER ###
# Out:
# Text(0, 0.5, 'Lake Erie levels')

# %%
### ANSWER ###
plt.plot(sup['Lake Superior annual averages'], sup['AnnAvg'], color="green")
plt.xlabel("Time")
plt.ylabel("Lake Superior levels")
### ANSWER ###
# Out:
# Text(0, 0.5, 'Lake Superior levels')

# %%
### ANSWER ###
plt.plot(mhu['Michigan-Huron annual averages'], mhu['AnnAvg'], color="red")
plt.xlabel("Time")
plt.ylabel("Michigan-Huron levels")
### ANSWER ###
# Out:
# Text(0, 0.5, 'Michigan-Huron levels')

# %% [markdown]
# &#9989; **Task:** Now, make a scatter plot of the Lake Ontario levels versus the Lake Erie levels and give it appropriate axis labels.

# %%
# Put your code here

# %%
### ANSWER ###
plt.scatter(eri['AnnAvg'], ont['AnnAvg'])
plt.xlabel("Lake Erie Levels")
plt.ylabel("Lake Ontario Levels")
### ANSWER ###
# Out:
# Text(0, 0.5, 'Lake Ontario Levels')

# %% [markdown]
# &#9989; **Task:** It turns out that seaborn offers more than one sort of plot style and you can change the style using `set_style()`. Refer to the [documentation](https://seaborn.pydata.org/tutorial/aesthetics.html#seaborn-figure-styles) to see what the different options are and then **try them out with your scatter plot**. You should also test out the `despine()` function and see what that does.

# %%
# Change the seaborn style here and remake your scatterplot
# test the "despine" function as well

# %%
### ANSWER ###
sns.set_style("white")
plt.scatter(eri['AnnAvg'], ont['AnnAvg'])
plt.xlabel("Lake Erie Levels")
plt.ylabel("Lake Ontario Levels")
sns.despine()
### ANSWER ###

# %% [markdown]
#  &#9989; **Question**: Which style do you prefer? When might you use one style versus another?

# %% [markdown]
# *Put your answer here*

# %% [markdown]
# Seaborn can also be really useful when you need to modify a plot to show up better in a presentation, on a poster, or in a paper. This can be done using the `set_context()` function.
#
# &#9989; **Task:** Refer to the [documention](https://seaborn.pydata.org/tutorial/aesthetics.html#scaling-plot-elements) and **make a new version of your scatter plot using each available context**.

# %%
# Put your code here and create new cells as necessary

# %%
### ANSWER ###
sns.set_context("talk")
sns.set_style("darkgrid")
plt.scatter(eri['AnnAvg'], ont['AnnAvg'])
plt.xlabel("Lake Erie Levels")
plt.ylabel("Lake Ontario Levels")
# Out:
# Text(0, 0.5, 'Lake Ontario Levels')

# %% [markdown]
# Finally, as mentioned earlier, Seaborn can be used to do data analysis as well. For example, you can use the [`jointplot()`](https://seaborn.pydata.org/generated/seaborn.jointplot.html) function to make a scatter plot similar to the one that you just made with matplotlib, but with additional information about the distribution of the data along each axis.
#
# &#9989; **Task:** Using the same data values that you used for the previous scatter plot, create a Seaborn [jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html). **Try using the `kind` argument to add a best fit line to the data.** The bars on the top and side of the plot show the histogram of the values for each lake.

# %%
# Put your jointplot code here

# %%
### ANSWER ###
sns.jointplot(x = eri['AnnAvg'], y = ont['AnnAvg'], kind="reg")
### ANSWER ###

# %% [markdown]
# &#9989; **Task:** Try out `jointplot` with other combinations of lake data as well

# %%
# Put some more example plots here

# %% [markdown]
# ---
# ## Part 2. Masking
#
# <img src="https://cf.ltkcdn.net/costumes/images/std-xs/96214-283x424-Phantommask2.webp" width="200px" align="right">
#
# Masking is an extremely important and absurdly useful tool that we will be adding to our coding tool box. Fundamentally, **"masking" is a process that allows us to select specific parts of our data that meet some condition.** Let’s work through some examples, to better understand what this means.
#
# Let’s start by looking at the random set of numbers.

# %%
import numpy as np

# %%
vals = np.array([3, 11, 6, 9, 7, 12, 8, 11, 5, 3, 15, 13])

# %% [markdown]
# &#9989; **Task:**
# Write a piece of code that uses a `for` loop and an `if` statement to identify all values of `vals` that are above 8. Append the values that meet this condition to a new list and print them out.

# %%
# Insert your code here

# %%
###ANSWER

new_vals = []
for hh in range(len(vals)):
    if vals[hh] > 8:
        new_vals.append(vals[hh])

print(new_vals)
# Out:
# [11, 9, 12, 11, 15, 13]

# %% [markdown]
# What we just did was select a subset of our data; specifically, all values in `vals` greater than 8. Now, let’s do the same thing using *masking*. The code below creates a mask and then uses that mask to select all of the data points that meet our condition.

# %%
mask = vals > 8
vals_masked = vals[mask]

# %% [markdown]
# &#9989; **Task:** Let’s break this code down, piece by piece. First, write a piece of code that prints `mask`.

# %%
# Insert your code here

# %%
###ANSWER
print(mask)
# Out:
# [False  True False  True False  True False  True False False  True  True]

# %% [markdown]
# &#9989; **Task:** You should see a list of Boolean values (`True` or `False`). Compare your `mask` values to the values of `vals`. What do you notice?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *Write your answer here*

# %% [markdown]
# ### ANSWER
#
# Should see that the mask is True wherever the condition is met and False everywhere else.

# %% [markdown]
# &#9989; **Task:** Now print out the values of `vals_masked`.

# %%
# Insert your code here

# %%
###ANSWER
print(vals_masked)
# Out:
# [11  9 12 11 15 13]

# %% [markdown]
# &#9989; **Task:** What values does `vals_masked` contain? How are these values connected to `vals`, `mask`, and the list that you created in 2.1?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *Write your answer here*

# %% [markdown]
# ### ANSWER
#
# Should say that it only contains values of `vals` that meet the mask condition, just like the list they made earlier.

# %% [markdown]
# &#9989; **Task:** Try tinkering with the mask generation code (line 1 from the cell in 2.1) by changing the condition (e.g., values below 8, values above 11, etc.). Print out the `mask` and `vals_masked` values for each one to convince yourself that the "masks" you create match your expectations.

# %%
# Insert code here

# %%
###ANSWER

mask1 = vals < 8
vals_masked1 = vals[mask1]
print(mask1)
print(vals_masked1)

mask2 = vals > 11
vals_masked2 = vals[mask2]
print(mask2)
print(vals_masked2)
# Out:
# [ True False  True False  True False False False  True  True False False]
# [3 6 7 5 3]
# [False False False False False  True False False False False  True  True]
# [12 15 13]

# %% [markdown]
# &#9989; **Task:** Take a moment and reflect. What is a mask? What does the process of masking data or values do?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *Write your answer here*

# %% [markdown]
# &#9989; **Task:** Before moving on, explain the concept of masking as if you were talking to someone who has never coded before.

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *Write your answer here*

# %% [markdown]
# ---
# ## Assignment wrap-up
#
# Please fill out the form that appears when you run the code below.  **You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://cmse.msu.edu/cmse801-pc-survey" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://cmse.msu.edu/cmse801-pc-survey"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "Pre-class assignments" folder, find the appropriate submission link, and upload it there.
#
# See you in class!

# %% [markdown]
# &#169; Copyright 2023,  The Department of Computational Mathematics, Science and Engineering.
