# %% [markdown]
# <img src="https://cmse.msu.edu/_assets/images/about/image001.png"
#      alt="CMSE Logo"
#      align="right"
#      height="400"
#      width="400" />
# # <font color=18453B>CMSE 801 - Day 16</font>
# ## Creating effective data visualizations
# ### March 12, 2026

# %% [markdown]
# ## General Course Announcements
#
# * Quiz 3 is **today** during the last 30-minutes of class.
# * Project Proposals were due.
#     * We'll use the first part of class to share your proposals with your group.
# * Homework 4 should come out on Wednesday.

# %% [markdown]
# ## Questions/comments from Day 16 PCA
#
# * Coming up with what story to tell with your data visualization can be challenging.
#     * The plot should do more than just represent a basic statistic or something that could easily just be shown with a small table.
#     * The visualization to create opportunities for insights not capture by the data alone.

# %% [markdown]
# ## Questions/comments from Day 16 PCA (cont.)
#
# * Seaborn can be a bit tricky to use as first, just like any new package, it takes time to digest the documentation and learn to use it.
#     * When you get stuck trying to use a new tool, as always, googling the issue you're running into can be a good way to find examples that do something similar to what you're trying to do.
#     * Seaborn can also be used as a simple way of changing the style of basic matplotlib plots. **We'll look at an example**.

# %% [markdown]
# ## It's important to think critically when we're presented with data visualizations
#
# * Make sure to ask yourself:
#     * What story is this visualization trying to tell?
#     * What might this data visualization be hiding?
#     * What do I need to know about the data in order to more deeply understand the visualization?

# %% [markdown]
# ## In order to determine the best way to visualize your data, you need to spend time exploring it!
#
# * Try visualizing the data in **more than one way**.
# * Think about whether or not you're interested in the relationships between features in your data, how the data varies with time, or something else!
#     * Perhaps you need to use one or more features to create a new feature that is derived from the original ones.
# * Explore the types of visualizations and think about which ones might be the right choice for the story you're trying to tell.
#     * The [Data Visualisation Catalogue](https://datavizcatalogue.com/) is a great tool for this. *Try the "Search by Function" feature*.

# %% [markdown]
# ## Let's look at a some ways we can use seaborn

# %%
# Some some imports out of the way
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Let's make some data to plot
# Create a list from 0 to 2pi with increments of 0.1
x_start = 0
x_stop = 2*np.pi
dx = 0.1
x = np.arange(x_start, x_stop, dx)

# Calculate sine and cosine using NumPy
sin_x = np.sin(x)
cos_x = np.cos(x)

# %%
# Turn on the seaborn styling
sns.set_theme()

plt.plot(x,sin_x)
plt.plot(x,cos_x)

# %%
# We can also modify the style; details here: https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set_style("whitegrid") # we can test "ticks", "dark", "whitegrid" as well

plt.plot(x,sin_x)
plt.plot(x,cos_x)

# %%
# We can also modify the style; details here: https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set_style("ticks")

plt.plot(x,sin_x)
plt.plot(x,cos_x)

# we can remove the "spines" as well
sns.despine()

# %%
# We can see all the things we can tweak with this command:
sns.axes_style()
# Out:
# {'axes.facecolor': '.9',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
# The base context is “notebook”, and the other contexts are “paper”, “talk”, and “poster”, which are version of the notebook parameters scaled by different values. Font elements can also be scaled independently of (but relative to) the other values.
sns.set_context("poster") # “paper”, “talk”, and “poster”

sns.set_style("white")

plt.plot(x,sin_x)
plt.plot(x,cos_x)

sns.despine()

# %% [markdown]
# ## But that's just the beginning!
#
# There are entirely new style of plots that available in Seaborn and you are encouraged to look at the [tutorial page](https://seaborn.pydata.org/tutorial.html) to explore how these can be used.

# %% [markdown]
# ## Project proposals
#
# * Take the next ~12 minutes to take turns presenting your project proposals to your group
#     * Try to keep track of time and limit yourselves to ~3 minutes per person
#     * You're encouraged to make time for getting some thoughts/feedback from your peers.

# %% [markdown]
# ## Goals for today
# * Briefly present the plot you came up with in the PCA to your groups and get some immediate feedback
# * Try to improve your plot based on the feedback and the information in the ICA -- **make sure you consider the provided plot criteria!**
#     * If there's time, you can present your updated plot to your group.
# * Quiz 3 starts at **9:20 am**. We will get ready around 9:15 am.

# %% [markdown]
# ## Looking forward - Day 17 PCA: Working with 2D NumPy arrays
#
# * You'll explore how information can be stored in two-dimensional (2D) numpy arrays.
#     * These are similar, in ways, to Pandas dataframes and information can be acces in ways similar to the "`:`" notation used in `.iloc`
# * You'll explore how to manipulate 2D arrays and how images can be stored as a collection of 2D arrays.
